# %% [markdown]
# We are going to use [Scrapy](https://scrapy.org/), which is a Python framework for automating data extraction from webpages. In this noteboodk we are following along a very good introduction to web scraping in general (along with some other tools that you might wish to explore) at the [Library Carpentry, "Webscraping with Python"
# October 2016](http://labs.timtom.ch/library-webscraping) site.
#
# Scrapy has already been installed in this notebook for you; but for reference, you can install it with `pip install scrapy`.

# %%
# !pip3 install scrapy
# !pip3 install pytesseract 
# !pip3 install img2table
# !pip3 install matplotlib
# Out:
# Requirement already satisfied: scrapy in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (2.15.0)
# Requirement already satisfied: cryptography>=37.0.0 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from scrapy) (46.0.7)
# Requirement already satisfied: cssselect>=0.9.1 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from scrapy) (1.4.0)
# Requirement already satisfied: defusedxml>=0.7.1 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from scrapy) (0.7.1)
# Requirement already satisfied: itemadapter>=0.1.0 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from scrapy) (0.13.1)
# Requirement already satisfied: itemloaders>=1.0.1 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from scrapy) (1.4.0)
# Requirement already satisfied: lxml>=4.6.4 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from scrapy) (6.1.0)
# Requirement already satisfied: packaging in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from scrapy) (26.0)
# Requirement already satisfied: parsel>=1.5.0 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from scrapy) (1.11.0)
# Requirement already satisfied: protego>=0.1.15 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from scrapy) (0.6.0)
# Requirement already satisfied: pydispatcher>=2.0.5 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from scrapy) (2.0.7)
# Requirement already satisfied: pyopenssl>=22.0.0 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from scrapy) (26.0.0)
# Requirement already satisfied: queuelib>=1.4.2 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from scrapy) (1.9.0)
# Requirement already satisfied: service-identity>=18.1.0 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from scrapy) (24.2.0)
# Requirement already satisfied: tldextract in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from scrapy) (5.3.1)
# Requirement already satisfied: twisted<=25.5.0,>=21.7.0 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from scrapy) (25.5.0)
# Requirement already satisfied: w3lib>=1.17.0 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from scrapy) (2.4.1)
# Requirement already satisfied: zope-interface>=5.1.0 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from scrapy) (8.3)
# Requirement already satisfied: attrs>=22.2.0 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from twisted<=25.5.0,>=21.7.0->scrapy) (26.1.0)
# Requirement already satisfied: automat>=24.8.0 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from twisted<=25.5.0,>=21.7.0->scrapy) (25.4.16)
# Requirement already satisfied: constantly>=15.1 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from twisted<=25.5.0,>=21.7.0->scrapy) (23.10.4)
# Requirement already satisfied: hyperlink>=17.1.1 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from twisted<=25.5.0,>=21.7.0->scrapy) (21.0.0)
# Requirement already satisfied: incremental>=24.7.0 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from twisted<=25.5.0,>=21.7.0->scrapy) (24.11.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from twisted<=25.5.0,>=21.7.0->scrapy) (4.15.0)
# Requirement already satisfied: cffi>=2.0.0 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from cryptography>=37.0.0->scrapy) (2.0.0)
# Requirement already satisfied: pycparser in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from cffi>=2.0.0->cryptography>=37.0.0->scrapy) (3.0)
# Requirement already satisfied: idna>=2.5 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from hyperlink>=17.1.1->twisted<=25.5.0,>=21.7.0->scrapy) (3.11)
# Requirement already satisfied: jmespath>=0.9.5 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from itemloaders>=1.0.1->scrapy) (1.1.0)
# Requirement already satisfied: pyasn1 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from service-identity>=18.1.0->scrapy) (0.6.3)
# Requirement already satisfied: pyasn1-modules in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from service-identity>=18.1.0->scrapy) (0.4.2)
# Requirement already satisfied: requests>=2.1.0 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from tldextract->scrapy) (2.33.1)
# Requirement already satisfied: requests-file>=1.4 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from tldextract->scrapy) (3.0.1)
# Requirement already satisfied: filelock>=3.0.8 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from tldextract->scrapy) (3.29.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from requests>=2.1.0->tldextract->scrapy) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from requests>=2.1.0->tldextract->scrapy) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from requests>=2.1.0->tldextract->scrapy) (2026.1.4)
# Collecting pytesseract
#   Downloading pytesseract-0.3.13-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=21.3 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from pytesseract) (26.0)
# Requirement already satisfied: Pillow>=8.0.0 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from pytesseract) (12.2.0)
# Downloading pytesseract-0.3.13-py3-none-any.whl (14 kB)
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.13
# Collecting img2table
#   Downloading img2table-0.0.12-py3-none-any.whl.metadata (13 kB)
# Collecting polars[pandas] (from img2table)
#   Downloading polars-1.40.0-py3-none-any.whl.metadata (10 kB)
# Collecting pyarrow>=7 (from img2table)
#   Downloading pyarrow-23.0.1-cp314-cp314-win_amd64.whl.metadata (3.1 kB)
# Requirement already satisfied: numpy in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from img2table) (2.4.4)
# Collecting pymupdf>=1.19.1 (from img2table)
#   Downloading pymupdf-1.27.2.2-cp310-abi3-win_amd64.whl.metadata (3.4 kB)
# Collecting opencv-python (from img2table)
#   Downloading opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting bs4 (from img2table)
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Collecting xlsxwriter>=3.0.6 (from img2table)
#   Downloading xlsxwriter-3.2.9-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: beautifulsoup4 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from bs4->img2table) (4.14.3)
# Requirement already satisfied: soupsieve>=1.6.1 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from beautifulsoup4->bs4->img2table) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from beautifulsoup4->bs4->img2table) (4.15.0)
# Collecting polars-runtime-32==1.40.0 (from polars[pandas]->img2table)
#   Downloading polars_runtime_32-1.40.0-cp310-abi3-win_amd64.whl.metadata (1.5 kB)
# Requirement already satisfied: pandas in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from polars[pandas]->img2table) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from pandas->polars[pandas]->img2table) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from pandas->polars[pandas]->img2table) (2026.1)
# Requirement already satisfied: six>=1.5 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from python-dateutil>=2.8.2->pandas->polars[pandas]->img2table) (1.17.0)
# Downloading img2table-0.0.12-py3-none-any.whl (43 kB)
# Downloading pyarrow-23.0.1-cp314-cp314-win_amd64.whl (28.2 MB)
#    ---------------------------------------- 0.0/28.2 MB ? eta -:--:--
#    ---------------------------- ----------- 20.4/28.2 MB 109.7 MB/s eta 0:00:01
#    ---------------------------------------- 28.2/28.2 MB 96.6 MB/s  0:00:00
# Downloading pymupdf-1.27.2.2-cp310-abi3-win_amd64.whl (19.2 MB)
#    ---------------------------------------- 0.0/19.2 MB ? eta -:--:--
#    ---------------------------------------- 19.2/19.2 MB 99.9 MB/s  0:00:00
# Downloading xlsxwriter-3.2.9-py3-none-any.whl (175 kB)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Downloading opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl (40.2 MB)
#    ---------------------------------------- 0.0/40.2 MB ? eta -:--:--
#    ----------------------- ---------------- 23.9/40.2 MB 118.6 MB/s eta 0:00:01
#    ---------------------------------------- 40.2/40.2 MB 103.4 MB/s  0:00:00
# Downloading polars-1.40.0-py3-none-any.whl (828 kB)
#    ---------------------------------------- 0.0/828.0 kB ? eta -:--:--
#    ---------------------------------------- 828.0/828.0 kB 31.7 MB/s  0:00:00
# Downloading polars_runtime_32-1.40.0-cp310-abi3-win_amd64.whl (51.8 MB)
#    ---------------------------------------- 0.0/51.8 MB ? eta -:--:--
#    ------------------- -------------------- 24.6/51.8 MB 118.6 MB/s eta 0:00:01
#    ------------------------------------- -- 48.5/51.8 MB 118.5 MB/s eta 0:00:01
#    ---------------------------------------- 51.8/51.8 MB 102.4 MB/s  0:00:00
# Installing collected packages: xlsxwriter, pymupdf, pyarrow, polars-runtime-32, opencv-python, polars, bs4, img2table
#
#    ---------------------------------------- 0/8 [xlsxwriter]
#    ---------------------------------------- 0/8 [xlsxwriter]
#    ---------------------------------------- 0/8 [xlsxwriter]
#    ----- ---------------------------------- 1/8 [pymupdf]
#    ----- ---------------------------------- 1/8 [pymupdf]
#    ----- ---------------------------------- 1/8 [pymupdf]
#    ----- ---------------------------------- 1/8 [pymupdf]
#    ----- ---------------------------------- 1/8 [pymupdf]
#    ----- ---------------------------------- 1/8 [pymupdf]
#    ---------- ----------------------------- 2/8 [pyarrow]
#    ---------- ----------------------------- 2/8 [pyarrow]
#    ---------- ----------------------------- 2/8 [pyarrow]
#    ---------- ----------------------------- 2/8 [pyarrow]
#    ---------- ----------------------------- 2/8 [pyarrow]
#    ---------- ----------------------------- 2/8 [pyarrow]
#    ---------- ----------------------------- 2/8 [pyarrow]
#    ---------- ----------------------------- 2/8 [pyarrow]
#    ---------- ----------------------------- 2/8 [pyarrow]
#    ---------- ----------------------------- 2/8 [pyarrow]
#    ---------- ----------------------------- 2/8 [pyarrow]
#    ---------- ----------------------------- 2/8 [pyarrow]
#    --------------- ------------------------ 3/8 [polars-runtime-32]
#    --------------- ------------------------ 3/8 [polars-runtime-32]
#    --------------- ------------------------ 3/8 [polars-runtime-32]
#    --------------- ------------------------ 3/8 [polars-runtime-32]
#    -------------------- ------------------- 4/8 [opencv-python]
#    -------------------- ------------------- 4/8 [opencv-python]
#    -------------------- ------------------- 4/8 [opencv-python]
#    -------------------- ------------------- 4/8 [opencv-python]
#    ------------------------- -------------- 5/8 [polars]
#    ------------------------- -------------- 5/8 [polars]
#    ------------------------- -------------- 5/8 [polars]
#    ------------------------- -------------- 5/8 [polars]
#    ------------------------- -------------- 5/8 [polars]
#    ------------------------- -------------- 5/8 [polars]
#    ------------------------- -------------- 5/8 [polars]
#    ------------------------- -------------- 5/8 [polars]
#    ------------------------- -------------- 5/8 [polars]
#    ------------------------- -------------- 5/8 [polars]
#    ------------------------- -------------- 5/8 [polars]
#    ------------------------- -------------- 5/8 [polars]
#    ------------------------- -------------- 5/8 [polars]
#    ----------------------------------- ---- 7/8 [img2table]
#    ---------------------------------------- 8/8 [img2table]
#
# Successfully installed bs4-0.0.2 img2table-0.0.12 opencv-python-4.13.0.92 polars-1.40.0 polars-runtime-32-1.40.0 pyarrow-23.0.1 pymupdf-1.27.2.2 xlsxwriter-3.2.9
# Requirement already satisfied: matplotlib in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from matplotlib) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
# !scrapy version
# Out:
# Scrapy 2.15.0

# %% [markdown]
# We're going to create a spider that scrapes the databases of the [Portable Antiquities Scheme](http://finds.org.uk).

# %%
# !scrapy startproject romanbrick
# Out:
# New Scrapy project 'romanbrick', using template directory 'C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages\scrapy\templates\project', created in:
#      C:\Users\Kegan\OneDrive - Carleton University\Work\Carleton University\StudentTester\odate-notebooks-2-test\Scraping\notebooks\romanbrick
#
#  You can start your first spider with:
#      cd romanbrick
#      scrapy genspider example example.com

# %% [markdown]
# If you go to the Home page (right-click on the jupyter logo at top left and open in a new tab) you'll see the new folder called `romanbrick`. _Inside_ that folder there is a new folder called (again) `romanbrick` and a file called `config`. The second `romanbrick` folder contains all of the plumbing for our spider. Your entire scrapy project then looks like this:
#
# ---
# ```
# romanbrick/            # the root project directory
#     scrapy.cfg      # deploy configuration file
#
#     romanbrick/        # project's Python module, you'll import your code from here
#         __init__.py
#
#         items.py        # Holds the structure of the data we want to collect
#
#         middlewares.py  # We aren't going to use this today.
#                         # A file to manipulate how spiders process input, in case pretending to be a normal HTTP browser doesn't work.
#
#         pipelines.py    # We aren't going to use this today, either.
#                         # Once our spider writes things to the "item," we can use pipelines to do additional processing before we export it.
#
#         settings.py # project settings file
#
#         spiders/        # a directory where you'll later put your spiders
#             __init__.py
#             ...
# ```
#
# ---

# %% [markdown]
# ## Spiders
#
# The `spiders` directory is where we're going to put our crawler (spiders...crawlers, geddit?). Spiders have three parts-
#
# 1. the starting URL(s)
# 2. a list of allowed domains, or places the crawler is allowed to go, for fear of downloading the entire internet (Not an idle fear, actually.)
# 3. a way of parsing the results, to get the data you're after.
#
# Scrapy makes this easy for us. Say we're interested in the archaeology of the Roman construction industry. At the PAS search page, we enter 'stamped brick' and end up with the following url:
#
# `https://finds.org.uk/database/search/results/q/stamped+brick`
#
# To create the spider, we tell Scrapy `scrapy genspider <SCRAPER NAME> <START URL>`, so:

# %%
# !scrapy genspider rbrickspider "finds.org.uk/database/search/results/q/stamped+brick"
# Out:
# Created spider 'rbrickspider' using template 'basic'

# %% [markdown]
# **Note** Open the file list (right-click on the Jupyter logo, open in a new tab so you don't close this notebook), and see where your `rbrickspider.py` file has been created. Tick off the check box, select 'move', and put it in the `spiders` folder, eg `\romanbrick\romanbrick\spiders`. Once it's moved, you can click on this file and it will open in the text editor - it'll look like this:
#
# ```
# # -*- coding: utf-8 -*-
# import scrapy
#
#
# class RbrickspiderSpider(scrapy.Spider):
#     name = 'rbrickspider'
#     allowed_domains = ['finds.org.uk/database/search/results/q/stamped+brick']
#     start_urls = ['http://finds.org.uk/database/search/results/q/stamped+brick/']
#
#     def parse(self, response):
#         pass
#
# ```
#
# Look at the `allowed_domains`. That's a bit too restrictive - only results that exactly match that pattern would be allowed. We want all the materials, so let's let the spider grab everything inside the top level domain. Change the pattern for `allowed_domains` to just the top level, then save the file. (psst: `finds.org.uk`).

# %% [markdown]
# Let's run it!

# %%
# %cd romanbrick
# Out:
# c:\Users\Kegan\OneDrive - Carleton University\Work\Carleton University\StudentTester\odate-notebooks-2-test\Scraping\notebooks\romanbrick

# %%
# !scrapy crawl rbrickspider -s DEPTH_LIMIT=1
# Out:
# 2026-04-20 11:34:40 [scrapy.utils.log] INFO: Scrapy 2.15.0 started (bot: romanbrick)
# 2026-04-20 11:34:40 [scrapy.utils.log] INFO: Versions:
# {'lxml': '6.1.0',
#  'libxml2': '2.11.9',
#  'cssselect': '1.4.0',
#  'parsel': '1.11.0',
#  'w3lib': '2.4.1',
#  'Twisted': '25.5.0',
#  'Python': '3.14.3 | packaged by Anaconda, Inc. | (main, Feb 24 2026, '
#            '22:45:56) [MSC v.1942 64 bit (AMD64)]',
#  'pyOpenSSL': '26.0.0 (OpenSSL 3.5.6 7 Apr 2026)',
#  'cryptography': '46.0.7',
#  'Platform': 'Windows-11-10.0.26200-SP0'}
# 2026-04-20 11:34:40 [scrapy.crawler] DEBUG: Using AsyncCrawlerProcess
# 2026-04-20 11:34:40 [asyncio] DEBUG: Using selector: SelectSelector
# 2026-04-20 11:34:40 [scrapy.addons] INFO: Enabled addons:
# []
# 2026-04-20 11:34:40 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2026-04-20 11:34:40 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.windows_events._WindowsSelectorEventLoop
# 2026-04-20 11:34:40 [scrapy.extensions.telnet] INFO: Telnet Password: 1fe75533f5707cde
# 2026-04-20 11:34:40 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.logcount.LogCount',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2026-04-20 11:34:40 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'romanbrick',
#  'CONCURRENT_REQUESTS_PER_DOMAIN': 1,
#  'DEPTH_LIMIT': '1',
#  'DOWNLOAD_DELAY': 1,
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'romanbrick.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['romanbrick.spiders']}
# 2026-04-20 11:34:40 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2026-04-20 11:34:40 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.start.StartSpiderMiddleware',
#  'scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2026-04-20 11:34:40 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2026-04-20 11:34:40 [scrapy.core.engine] INFO: Spider opened
# 2026-04-20 11:34:40 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2026-04-20 11:34:40 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2026-04-20 11:34:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://finds.org.uk/robots.txt> (referer: None)
# 2026-04-20 11:34:41 [scrapy.core.engine] DEBUG: Crawled (403) <GET https://finds.org.uk/database/search/results/q/stamped+brick> (referer: None)
# 2026-04-20 11:34:41 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <403 https://finds.org.uk/database/search/results/q/stamped+brick>: HTTP status code is not handled or not allowed
# 2026-04-20 11:34:41 [scrapy.core.engine] INFO: Closing spider (finished)
# 2026-04-20 11:34:41 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 483,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 5479,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 1,
#  'downloader/response_status_count/403': 1,
#  'elapsed_time_seconds': 1.049199,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2026, 4, 20, 15, 34, 41, 540144, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 6609,
#  'httpcompression/response_count': 2,
#  'httperror/response_ignored_count': 1,
#  'httperror/response_ignored_status_count/403': 1,
#  'items_per_minute': 0.0,
#  'log_count/DEBUG': 2,
#  'log_count/INFO': 4,
#  'response_received_count': 2,
#  'responses_per_minute': 120.0,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2026, 4, 20, 15, 34, 40, 490945, tzinfo=datetime.timezone.utc)}
# 2026-04-20 11:34:41 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# It worked! You know this by the `downloader/response_status_count/200` - the scraper was able to reach the webpage and interact with it. However, because we haven't told the spider _what_ to parse, it hasn't grabbed anything.

# %% [markdown]
# Add the following to your `rbrickspider.py` file (which is in `\romanbrick\romanbrick\spiders` remember):
#
# ```
#  def parse(self, response):
#         with open("test.html", 'wb') as file:
#             file.write(response.body)
# ```
#
# This writes the html of the page to file. Save that, then run the spider again in the block below. Be careful with the copying and pasting; python is very fussy about tabs versus spaces and so on. If you get an error 'unexpected indent' you need to make sure that you haven't mixed spaces with tabs.

# %%
# paste your crawl command in this block and run it.
# !scrapy crawl rbrickspider -s DEPTH_LIMIT=1
# Out:
# 2026-04-20 11:36:26 [scrapy.utils.log] INFO: Scrapy 2.15.0 started (bot: romanbrick)
# 2026-04-20 11:36:26 [scrapy.utils.log] INFO: Versions:
# {'lxml': '6.1.0',
#  'libxml2': '2.11.9',
#  'cssselect': '1.4.0',
#  'parsel': '1.11.0',
#  'w3lib': '2.4.1',
#  'Twisted': '25.5.0',
#  'Python': '3.14.3 | packaged by Anaconda, Inc. | (main, Feb 24 2026, '
#            '22:45:56) [MSC v.1942 64 bit (AMD64)]',
#  'pyOpenSSL': '26.0.0 (OpenSSL 3.5.6 7 Apr 2026)',
#  'cryptography': '46.0.7',
#  'Platform': 'Windows-11-10.0.26200-SP0'}
# 2026-04-20 11:36:26 [scrapy.crawler] DEBUG: Using AsyncCrawlerProcess
# 2026-04-20 11:36:26 [asyncio] DEBUG: Using selector: SelectSelector
# 2026-04-20 11:36:26 [scrapy.addons] INFO: Enabled addons:
# []
# 2026-04-20 11:36:26 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2026-04-20 11:36:26 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.windows_events._WindowsSelectorEventLoop
# 2026-04-20 11:36:26 [scrapy.extensions.telnet] INFO: Telnet Password: 6e19680092caa9bb
# 2026-04-20 11:36:26 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.logcount.LogCount',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2026-04-20 11:36:26 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'romanbrick',
#  'CONCURRENT_REQUESTS_PER_DOMAIN': 1,
#  'DEPTH_LIMIT': '1',
#  'DOWNLOAD_DELAY': 1,
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'romanbrick.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['romanbrick.spiders']}
# 2026-04-20 11:36:26 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2026-04-20 11:36:26 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.start.StartSpiderMiddleware',
#  'scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2026-04-20 11:36:26 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2026-04-20 11:36:26 [scrapy.core.engine] INFO: Spider opened
# 2026-04-20 11:36:26 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2026-04-20 11:36:26 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2026-04-20 11:36:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://finds.org.uk/robots.txt> (referer: None)
# 2026-04-20 11:36:27 [scrapy.core.engine] DEBUG: Crawled (403) <GET https://finds.org.uk/database/search/results/q/stamped+brick> (referer: None)
# 2026-04-20 11:36:27 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <403 https://finds.org.uk/database/search/results/q/stamped+brick>: HTTP status code is not handled or not allowed
# 2026-04-20 11:36:27 [scrapy.core.engine] INFO: Closing spider (finished)
# 2026-04-20 11:36:27 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 483,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 5489,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 1,
#  'downloader/response_status_count/403': 1,
#  'elapsed_time_seconds': 1.374134,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2026, 4, 20, 15, 36, 27, 666721, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 6609,
#  'httpcompression/response_count': 2,
#  'httperror/response_ignored_count': 1,
#  'httperror/response_ignored_status_count/403': 1,
#  'items_per_minute': 0.0,
#  'log_count/DEBUG': 2,
#  'log_count/INFO': 4,
#  'response_received_count': 2,
#  'responses_per_minute': 120.0,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2026, 4, 20, 15, 36, 26, 292587, tzinfo=datetime.timezone.utc)}
# 2026-04-20 11:36:27 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# If you check the contents of this directory with the `ls` command, you should see a new file `test.html`

# %%
# !ls
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# Let's look at the first few lines of the file with the `head` command. Have we actually scraped anything?

# %%
# !head test.html

# %% [markdown]
# But saving webpages isn't the point of scraping; rather, we want the data itself. In the file list screen (accessed by clicking on the Jupyter logo at top left) tick the box beside `test.html` and then select `edit`. Let's scroll through the results. Examine the html, paying attention to the `<div>` elements that wrap the information we want, and how these elements nest one within the other.
#
# We can tell Scrapy which of those bits of information we want to collect using [Xpath Selectors](https://resbazsql.github.io/lc-webscraping/02-dom/). Many websites are built by pulling data out of a database and then displaying it by running it through a 'document object model'; this model tells the webpage where to put and how to display the various information. An 'xpath' lets us specify which object in this model we want. We tell Scrapy the xpath to the info, and it duly collects all the data found in that path.
#
# There are a variety of ways of finding the correct xpath; some people recommend this [scraper extension for chrome](https://chrome.google.com/webstore/detail/scraper/mbigbapnjcgaffohmbkdlecaccepngjd).
#
# If you open a new terminal in Jupyter, type `cd romanbrick` and then
#
# `scrapy shell "https://finds.org.uk/database/search/results/q/stamped+brick"`
#
# you can try testing different xpath combinations and test what results you get using the `response.xpath` command:
#
# `>>> response.xpath("//THE XPATH SELECTOR GOES IN HERE AND MAKE SURE TO CHANGE QUOTES TO SINGLE QUOTES IF NECESSARY")`
#
#
# After some examination, we see that `//*[@id='preview']/p/text()` will get the information we want.
#
# Edit `rbrickspider.py` so that you're parsing for just the data:
#
# ```
#     def parse(self, response):
#         print(response.xpath("//*[@id='preview']/p/text()").extract())
#
# ```
#
# Now run
# ```
# !scrapy crawl rbrickspider -s DEPTH_LIMIT=1
# ```
#
# in the code block below. Check with `!pwd` to make sure you're in `jovyan\romanbrick` first.

# %%
#past the code here

# %% [markdown]
# We're getting there! But all of the data is coming in a big mess. Edit `rbrickspider.py` so that you're parsing for just the data:
#
# ```
#     def parse(self, response):
#         for resource in response.xpath("//*[@id='preview']/p/text()"):
#             print(resource.extract())
# ```
#
# Now run
# ```
# !scrapy crawl rbrickspider -s DEPTH_LIMIT=1
# ```
#
# (By the way - if you ever find that nothing happens when you run the scrapy crawl command, try refreshing the browser window and re-running the `%cd romanbrick` command first).

# %%
# put your code here

# %% [markdown]
# When you look at the Finds.org.uk search results' page underlying html using Chrome's inspector, you'll notice that the images are all contained within the `ul` tag. You can right click on that html and select 'copy xpath'. You should get `//*[@id='preview']/ul/li/div/a`. Swap that into your spider and run it.

# %% [markdown]
# At this point, you'll be getting the hang of it.  For the final step of writing your data to csv, please scroll down to the [Writing to a csv](https://resbazsql.github.io/lc-webscraping/04-scrapy/) section of the Library Carpentry tutorial - but make sure you right-click on that link and open in a new tab! You now know how to grab two different sets of data from the finds page. Complete the tutorial so that you end up with a table of results from the finds.org.uk webpage.
#
# Save your work, and remember to file -> download as -> notebook when you're done. Remember that this binder will time out after ten minutes.
