# %% [markdown]
# # Schelling Segregation Model
#
# ## Background
#
# The Schelling (1971) segregation model is a classic of agent-based modeling, demonstrating how agents following simple rules lead to the emergence of qualitatively different macro-level outcomes. Agents are randomly placed on a grid. There are two types of agents, one constituting the majority and the other the minority. All agents want a certain number (generally, 3) of their 8 surrounding neighbors to be of the same type in order for them to be happy. Unhappy agents will move to a random available grid space. While individual agents do not have a preference for a segregated outcome (e.g. they would be happy with 3 similar neighbors and 5 different ones), the aggregate outcome is nevertheless heavily segregated.
#
# ## Implementation
#
# This is a demonstration of running a Mesa model in an IPython Notebook. The actual model and agent code are implemented in Schelling.py, in the same directory as this notebook. Below, we will import the model class, instantiate it, run it, and plot the time series of the number of happy agents.

# %%
# !pip3 install mesa
# !pip3 install numpy
# !pip3 install matplotlib
# !pip3 install pandas
# !pip3 install networkx
# Out:
# Collecting mesa
#   Downloading mesa-3.5.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from mesa) (2.4.4)
# Requirement already satisfied: pandas in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from mesa) (3.0.2)
# Collecting scipy (from mesa)
#   Downloading scipy-1.17.1-cp314-cp314-win_amd64.whl.metadata (60 kB)
# Collecting tqdm (from mesa)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from pandas->mesa) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from pandas->mesa) (2026.1)
# Requirement already satisfied: six>=1.5 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from python-dateutil>=2.8.2->pandas->mesa) (1.17.0)
# Requirement already satisfied: colorama in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from tqdm->mesa) (0.4.6)
# Downloading mesa-3.5.1-py3-none-any.whl (275 kB)
# Downloading scipy-1.17.1-cp314-cp314-win_amd64.whl (37.3 MB)
#    ---------------------------------------- 0.0/37.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/37.3 MB ? eta -:--:--
#    ---------------------------------------- 0.3/37.3 MB ? eta -:--:--
#    ---------------------------------------- 0.3/37.3 MB ? eta -:--:--
#     --------------------------------------- 0.5/37.3 MB 623.5 kB/s eta 0:00:59
#     --------------------------------------- 0.5/37.3 MB 623.5 kB/s eta 0:00:59
#     --------------------------------------- 0.8/37.3 MB 586.9 kB/s eta 0:01:03
#     --------------------------------------- 0.8/37.3 MB 586.9 kB/s eta 0:01:03
#    - -------------------------------------- 1.0/37.3 MB 593.2 kB/s eta 0:01:02
#    - -------------------------------------- 1.0/37.3 MB 593.2 kB/s eta 0:01:02
#    - -------------------------------------- 1.0/37.3 MB 593.2 kB/s eta 0:01:02
#    - -------------------------------------- 1.3/37.3 MB 546.9 kB/s eta 0:01:06
#    - -------------------------------------- 1.3/37.3 MB 546.9 kB/s eta 0:01:06
#    - -------------------------------------- 1.6/37.3 MB 580.3 kB/s eta 0:01:02
#    - -------------------------------------- 1.6/37.3 MB 580.3 kB/s eta 0:01:02
#    - -------------------------------------- 1.6/37.3 MB 580.3 kB/s eta 0:01:02
#    - -------------------------------------- 1.6/37.3 MB 580.3 kB/s eta 0:01:02
#    - -------------------------------------- 1.6/37.3 MB 580.3 kB/s eta 0:01:02
#    - -------------------------------------- 1.8/37.3 MB 472.2 kB/s eta 0:01:16
#    - -------------------------------------- 1.8/37.3 MB 472.2 kB/s eta 0:01:16
#    - -------------------------------------- 1.8/37.3 MB 472.2 kB/s eta 0:01:16
#    - -------------------------------------- 1.8/37.3 MB 472.2 kB/s eta 0:01:16
#    - -------------------------------------- 1.8/37.3 MB 472.2 kB/s eta 0:01:16
#    - -------------------------------------- 1.8/37.3 MB 472.2 kB/s eta 0:01:16
#    -- ------------------------------------- 2.1/37.3 MB 414.5 kB/s eta 0:01:25
#    -- ------------------------------------- 2.1/37.3 MB 414.5 kB/s eta 0:01:25
#    -- ------------------------------------- 2.4/37.3 MB 429.2 kB/s eta 0:01:22
#    -- ------------------------------------- 2.4/37.3 MB 429.2 kB/s eta 0:01:22
#    -- ------------------------------------- 2.6/37.3 MB 438.4 kB/s eta 0:01:20
#    -- ------------------------------------- 2.6/37.3 MB 438.4 kB/s eta 0:01:20
#    --- ------------------------------------ 2.9/37.3 MB 448.6 kB/s eta 0:01:17
#    --- ------------------------------------ 2.9/37.3 MB 448.6 kB/s eta 0:01:17
#    --- ------------------------------------ 2.9/37.3 MB 448.6 kB/s eta 0:01:17
#    --- ------------------------------------ 3.1/37.3 MB 455.6 kB/s eta 0:01:15
#    --- ------------------------------------ 3.1/37.3 MB 455.6 kB/s eta 0:01:15
#    --- ------------------------------------ 3.1/37.3 MB 455.6 kB/s eta 0:01:15
#    --- ------------------------------------ 3.1/37.3 MB 455.6 kB/s eta 0:01:15
#    --- ------------------------------------ 3.4/37.3 MB 433.3 kB/s eta 0:01:19
#    --- ------------------------------------ 3.4/37.3 MB 433.3 kB/s eta 0:01:19
#    --- ------------------------------------ 3.4/37.3 MB 433.3 kB/s eta 0:01:19
#    --- ------------------------------------ 3.4/37.3 MB 433.3 kB/s eta 0:01:19
#    --- ------------------------------------ 3.4/37.3 MB 433.3 kB/s eta 0:01:19
#    --- ------------------------------------ 3.4/37.3 MB 433.3 kB/s eta 0:01:19
#    --- ------------------------------------ 3.4/37.3 MB 433.3 kB/s eta 0:01:19
#    --- ------------------------------------ 3.7/37.3 MB 391.9 kB/s eta 0:01:26
#    --- ------------------------------------ 3.7/37.3 MB 391.9 kB/s eta 0:01:26
#    --- ------------------------------------ 3.7/37.3 MB 391.9 kB/s eta 0:01:26
#    --- ------------------------------------ 3.7/37.3 MB 391.9 kB/s eta 0:01:26
#    ---- ----------------------------------- 3.9/37.3 MB 388.5 kB/s eta 0:01:26
#    ---- ----------------------------------- 3.9/37.3 MB 388.5 kB/s eta 0:01:26
#    ---- ----------------------------------- 3.9/37.3 MB 388.5 kB/s eta 0:01:26
#    ---- ----------------------------------- 3.9/37.3 MB 388.5 kB/s eta 0:01:26
#    ---- ----------------------------------- 3.9/37.3 MB 388.5 kB/s eta 0:01:26
#    ---- ----------------------------------- 3.9/37.3 MB 388.5 kB/s eta 0:01:26
#    ---- ----------------------------------- 4.2/37.3 MB 369.6 kB/s eta 0:01:30
#    ---- ----------------------------------- 4.2/37.3 MB 369.6 kB/s eta 0:01:30
#    ---- ----------------------------------- 4.2/37.3 MB 369.6 kB/s eta 0:01:30
#    ---- ----------------------------------- 4.2/37.3 MB 369.6 kB/s eta 0:01:30
#    ---- ----------------------------------- 4.2/37.3 MB 369.6 kB/s eta 0:01:30
#    ---- ----------------------------------- 4.2/37.3 MB 369.6 kB/s eta 0:01:30
#    ---- ----------------------------------- 4.5/37.3 MB 353.7 kB/s eta 0:01:33
#    ---- ----------------------------------- 4.5/37.3 MB 353.7 kB/s eta 0:01:33
#    ----- ---------------------------------- 4.7/37.3 MB 359.5 kB/s eta 0:01:31
#    ----- ---------------------------------- 4.7/37.3 MB 359.5 kB/s eta 0:01:31
#    ----- ---------------------------------- 5.0/37.3 MB 369.7 kB/s eta 0:01:28
#    ----- ---------------------------------- 5.0/37.3 MB 369.7 kB/s eta 0:01:28
#    ----- ---------------------------------- 5.0/37.3 MB 369.7 kB/s eta 0:01:28
#    ----- ---------------------------------- 5.2/37.3 MB 370.8 kB/s eta 0:01:27
#    ----- ---------------------------------- 5.2/37.3 MB 370.8 kB/s eta 0:01:27
#    ----- ---------------------------------- 5.2/37.3 MB 370.8 kB/s eta 0:01:27
#    ----- ---------------------------------- 5.2/37.3 MB 370.8 kB/s eta 0:01:27
#    ----- ---------------------------------- 5.5/37.3 MB 368.8 kB/s eta 0:01:27
#    ----- ---------------------------------- 5.5/37.3 MB 368.8 kB/s eta 0:01:27
#    ----- ---------------------------------- 5.5/37.3 MB 368.8 kB/s eta 0:01:27
#    ------ --------------------------------- 5.8/37.3 MB 370.8 kB/s eta 0:01:26
#    ------ --------------------------------- 5.8/37.3 MB 370.8 kB/s eta 0:01:26
#    ------ --------------------------------- 5.8/37.3 MB 370.8 kB/s eta 0:01:26
#    ------ --------------------------------- 5.8/37.3 MB 370.8 kB/s eta 0:01:26
#    ------ --------------------------------- 6.0/37.3 MB 371.5 kB/s eta 0:01:25
#    ------ --------------------------------- 6.0/37.3 MB 371.5 kB/s eta 0:01:25
#    ------ --------------------------------- 6.0/37.3 MB 371.5 kB/s eta 0:01:25
#    ------ --------------------------------- 6.0/37.3 MB 371.5 kB/s eta 0:01:25
#    ------ --------------------------------- 6.3/37.3 MB 369.2 kB/s eta 0:01:24
#    ------ --------------------------------- 6.3/37.3 MB 369.2 kB/s eta 0:01:24
#    ------- -------------------------------- 6.6/37.3 MB 373.8 kB/s eta 0:01:23
#    ------- -------------------------------- 6.6/37.3 MB 373.8 kB/s eta 0:01:23
#    ------- -------------------------------- 6.6/37.3 MB 373.8 kB/s eta 0:01:23
#    ------- -------------------------------- 6.8/37.3 MB 378.2 kB/s eta 0:01:21
#    ------- -------------------------------- 6.8/37.3 MB 378.2 kB/s eta 0:01:21
#    ------- -------------------------------- 6.8/37.3 MB 378.2 kB/s eta 0:01:21
#    ------- -------------------------------- 7.1/37.3 MB 376.4 kB/s eta 0:01:21
#    ------- -------------------------------- 7.1/37.3 MB 376.4 kB/s eta 0:01:21
#    ------- -------------------------------- 7.1/37.3 MB 376.4 kB/s eta 0:01:21
#    ------- -------------------------------- 7.3/37.3 MB 380.3 kB/s eta 0:01:19
#    -------- ------------------------------- 7.6/37.3 MB 387.7 kB/s eta 0:01:17
#    -------- ------------------------------- 7.6/37.3 MB 387.7 kB/s eta 0:01:17
#    -------- ------------------------------- 7.9/37.3 MB 395.9 kB/s eta 0:01:15
#    -------- ------------------------------- 8.1/37.3 MB 403.9 kB/s eta 0:01:13
#    -------- ------------------------------- 8.1/37.3 MB 403.9 kB/s eta 0:01:13
#    -------- ------------------------------- 8.1/37.3 MB 403.9 kB/s eta 0:01:13
#    -------- ------------------------------- 8.4/37.3 MB 406.4 kB/s eta 0:01:12
#    -------- ------------------------------- 8.4/37.3 MB 406.4 kB/s eta 0:01:12
#    -------- ------------------------------- 8.4/37.3 MB 406.4 kB/s eta 0:01:12
#    -------- ------------------------------- 8.4/37.3 MB 406.4 kB/s eta 0:01:12
#    -------- ------------------------------- 8.4/37.3 MB 406.4 kB/s eta 0:01:12
#    -------- ------------------------------- 8.4/37.3 MB 406.4 kB/s eta 0:01:12
#    --------- ------------------------------ 8.7/37.3 MB 394.0 kB/s eta 0:01:13
#    --------- ------------------------------ 8.7/37.3 MB 394.0 kB/s eta 0:01:13
#    --------- ------------------------------ 8.7/37.3 MB 394.0 kB/s eta 0:01:13
#    --------- ------------------------------ 8.7/37.3 MB 394.0 kB/s eta 0:01:13
#    --------- ------------------------------ 8.7/37.3 MB 394.0 kB/s eta 0:01:13
#    --------- ------------------------------ 8.9/37.3 MB 389.2 kB/s eta 0:01:13
#    --------- ------------------------------ 8.9/37.3 MB 389.2 kB/s eta 0:01:13
#    --------- ------------------------------ 8.9/37.3 MB 389.2 kB/s eta 0:01:13
#    --------- ------------------------------ 9.2/37.3 MB 390.7 kB/s eta 0:01:12
#    --------- ------------------------------ 9.2/37.3 MB 390.7 kB/s eta 0:01:12
#    --------- ------------------------------ 9.2/37.3 MB 390.7 kB/s eta 0:01:12
#    ---------- ----------------------------- 9.4/37.3 MB 388.4 kB/s eta 0:01:12
#    ---------- ----------------------------- 9.4/37.3 MB 388.4 kB/s eta 0:01:12
#    ---------- ----------------------------- 9.4/37.3 MB 388.4 kB/s eta 0:01:12
#    ---------- ----------------------------- 9.4/37.3 MB 388.4 kB/s eta 0:01:12
#    ---------- ----------------------------- 9.4/37.3 MB 388.4 kB/s eta 0:01:12
#    ---------- ----------------------------- 9.7/37.3 MB 383.2 kB/s eta 0:01:12
#    ---------- ----------------------------- 9.7/37.3 MB 383.2 kB/s eta 0:01:12
#    ---------- ----------------------------- 9.7/37.3 MB 383.2 kB/s eta 0:01:12
#    ---------- ----------------------------- 10.0/37.3 MB 386.6 kB/s eta 0:01:11
#    ---------- ----------------------------- 10.2/37.3 MB 391.3 kB/s eta 0:01:10
#    ---------- ----------------------------- 10.2/37.3 MB 391.3 kB/s eta 0:01:10
#    ---------- ----------------------------- 10.2/37.3 MB 391.3 kB/s eta 0:01:10
#    ---------- ----------------------------- 10.2/37.3 MB 391.3 kB/s eta 0:01:10
#    ----------- ---------------------------- 10.5/37.3 MB 389.4 kB/s eta 0:01:09
#    ----------- ---------------------------- 10.5/37.3 MB 389.4 kB/s eta 0:01:09
#    ----------- ---------------------------- 10.5/37.3 MB 389.4 kB/s eta 0:01:09
#    ----------- ---------------------------- 10.5/37.3 MB 389.4 kB/s eta 0:01:09
#    ----------- ---------------------------- 10.7/37.3 MB 387.8 kB/s eta 0:01:09
#    ----------- ---------------------------- 10.7/37.3 MB 387.8 kB/s eta 0:01:09
#    ----------- ---------------------------- 10.7/37.3 MB 387.8 kB/s eta 0:01:09
#    ----------- ---------------------------- 11.0/37.3 MB 389.7 kB/s eta 0:01:08
#    ----------- ---------------------------- 11.0/37.3 MB 389.7 kB/s eta 0:01:08
#    ------------ --------------------------- 11.3/37.3 MB 393.3 kB/s eta 0:01:07
#    ------------ --------------------------- 11.3/37.3 MB 393.3 kB/s eta 0:01:07
#    ------------ --------------------------- 11.5/37.3 MB 396.9 kB/s eta 0:01:05
#    ------------ --------------------------- 11.5/37.3 MB 396.9 kB/s eta 0:01:05
#    ------------ --------------------------- 11.5/37.3 MB 396.9 kB/s eta 0:01:05
#    ------------ --------------------------- 11.5/37.3 MB 396.9 kB/s eta 0:01:05
#    ------------ --------------------------- 11.8/37.3 MB 393.5 kB/s eta 0:01:05
#    ------------ --------------------------- 11.8/37.3 MB 393.5 kB/s eta 0:01:05
#    ------------ --------------------------- 11.8/37.3 MB 393.5 kB/s eta 0:01:05
#    ------------ --------------------------- 11.8/37.3 MB 393.5 kB/s eta 0:01:05
#    ------------ --------------------------- 11.8/37.3 MB 393.5 kB/s eta 0:01:05
#    ------------ --------------------------- 11.8/37.3 MB 393.5 kB/s eta 0:01:05
#    ------------ --------------------------- 11.8/37.3 MB 393.5 kB/s eta 0:01:05
#    ------------ --------------------------- 12.1/37.3 MB 377.7 kB/s eta 0:01:07
#    ------------ --------------------------- 12.1/37.3 MB 377.7 kB/s eta 0:01:07
#    ------------ --------------------------- 12.1/37.3 MB 377.7 kB/s eta 0:01:07
#    ------------ --------------------------- 12.1/37.3 MB 377.7 kB/s eta 0:01:07
#    ------------ --------------------------- 12.1/37.3 MB 377.7 kB/s eta 0:01:07
#    ------------- -------------------------- 12.3/37.3 MB 368.7 kB/s eta 0:01:08
#    ------------- -------------------------- 12.3/37.3 MB 368.7 kB/s eta 0:01:08
#    ------------- -------------------------- 12.3/37.3 MB 368.7 kB/s eta 0:01:08
#    ------------- -------------------------- 12.3/37.3 MB 368.7 kB/s eta 0:01:08
#    ------------- -------------------------- 12.6/37.3 MB 366.4 kB/s eta 0:01:08
#    ------------- -------------------------- 12.6/37.3 MB 366.4 kB/s eta 0:01:08
#    ------------- -------------------------- 12.8/37.3 MB 370.6 kB/s eta 0:01:06
#    ------------- -------------------------- 12.8/37.3 MB 370.6 kB/s eta 0:01:06
#    ------------- -------------------------- 12.8/37.3 MB 370.6 kB/s eta 0:01:06
#    ------------- -------------------------- 12.8/37.3 MB 370.6 kB/s eta 0:01:06
#    -------------- ------------------------- 13.1/37.3 MB 374.6 kB/s eta 0:01:05
#    -------------- ------------------------- 13.1/37.3 MB 374.6 kB/s eta 0:01:05
#    -------------- ------------------------- 13.1/37.3 MB 374.6 kB/s eta 0:01:05
#    -------------- ------------------------- 13.4/37.3 MB 375.8 kB/s eta 0:01:04
#    -------------- ------------------------- 13.4/37.3 MB 375.8 kB/s eta 0:01:04
#    -------------- ------------------------- 13.6/37.3 MB 376.4 kB/s eta 0:01:03
#    -------------- ------------------------- 13.6/37.3 MB 376.4 kB/s eta 0:01:03
#    -------------- ------------------------- 13.9/37.3 MB 377.0 kB/s eta 0:01:03
#    -------------- ------------------------- 13.9/37.3 MB 377.0 kB/s eta 0:01:03
#    --------------- ------------------------ 14.2/37.3 MB 377.8 kB/s eta 0:01:02
#    --------------- ------------------------ 14.2/37.3 MB 377.8 kB/s eta 0:01:02
#    --------------- ------------------------ 14.2/37.3 MB 377.8 kB/s eta 0:01:02
#    --------------- ------------------------ 14.2/37.3 MB 377.8 kB/s eta 0:01:02
#    --------------- ------------------------ 14.4/37.3 MB 377.9 kB/s eta 0:01:01
#    --------------- ------------------------ 14.7/37.3 MB 382.7 kB/s eta 0:01:00
#    --------------- ------------------------ 14.7/37.3 MB 382.7 kB/s eta 0:01:00
#    ---------------- ----------------------- 15.2/37.3 MB 395.0 kB/s eta 0:00:56
#    ---------------- ----------------------- 15.5/37.3 MB 412.2 kB/s eta 0:00:53
#    ---------------- ----------------------- 15.7/37.3 MB 418.5 kB/s eta 0:00:52
#    ----------------- ---------------------- 16.0/37.3 MB 424.5 kB/s eta 0:00:51
#    ----------------- ---------------------- 16.3/37.3 MB 430.2 kB/s eta 0:00:49
#    ----------------- ---------------------- 16.3/37.3 MB 430.2 kB/s eta 0:00:49
#    ----------------- ---------------------- 16.5/37.3 MB 433.8 kB/s eta 0:00:48
#    ----------------- ---------------------- 16.5/37.3 MB 433.8 kB/s eta 0:00:48
#    ----------------- ---------------------- 16.5/37.3 MB 433.8 kB/s eta 0:00:48
#    ----------------- ---------------------- 16.5/37.3 MB 433.8 kB/s eta 0:00:48
#    ----------------- ---------------------- 16.5/37.3 MB 433.8 kB/s eta 0:00:48
#    ----------------- ---------------------- 16.5/37.3 MB 433.8 kB/s eta 0:00:48
#    ----------------- ---------------------- 16.8/37.3 MB 428.4 kB/s eta 0:00:48
#    ----------------- ---------------------- 16.8/37.3 MB 428.4 kB/s eta 0:00:48
#    ----------------- ---------------------- 16.8/37.3 MB 428.4 kB/s eta 0:00:48
#    ----------------- ---------------------- 16.8/37.3 MB 428.4 kB/s eta 0:00:48
#    ------------------ --------------------- 17.0/37.3 MB 432.3 kB/s eta 0:00:47
#    ------------------ --------------------- 17.0/37.3 MB 432.3 kB/s eta 0:00:47
#    ------------------ --------------------- 17.3/37.3 MB 443.9 kB/s eta 0:00:46
#    ------------------ --------------------- 17.6/37.3 MB 449.2 kB/s eta 0:00:44
#    ------------------- -------------------- 17.8/37.3 MB 455.2 kB/s eta 0:00:43
#    ------------------- -------------------- 18.1/37.3 MB 460.7 kB/s eta 0:00:42
#    ------------------- -------------------- 18.1/37.3 MB 460.7 kB/s eta 0:00:42
#    ------------------- -------------------- 18.6/37.3 MB 472.3 kB/s eta 0:00:40
#    ------------------- -------------------- 18.6/37.3 MB 472.3 kB/s eta 0:00:40
#    -------------------- ------------------- 18.9/37.3 MB 476.8 kB/s eta 0:00:39
#    -------------------- ------------------- 18.9/37.3 MB 476.8 kB/s eta 0:00:39
#    -------------------- ------------------- 19.1/37.3 MB 473.4 kB/s eta 0:00:39
#    -------------------- ------------------- 19.1/37.3 MB 473.4 kB/s eta 0:00:39
#    -------------------- ------------------- 19.4/37.3 MB 477.5 kB/s eta 0:00:38
#    -------------------- ------------------- 19.4/37.3 MB 477.5 kB/s eta 0:00:38
#    --------------------- ------------------ 19.7/37.3 MB 484.3 kB/s eta 0:00:37
#    --------------------- ------------------ 19.7/37.3 MB 484.3 kB/s eta 0:00:37
#    --------------------- ------------------ 19.9/37.3 MB 487.7 kB/s eta 0:00:36
#    --------------------- ------------------ 20.2/37.3 MB 492.1 kB/s eta 0:00:35
#    --------------------- ------------------ 20.2/37.3 MB 492.1 kB/s eta 0:00:35
#    --------------------- ------------------ 20.4/37.3 MB 496.3 kB/s eta 0:00:34
#    ---------------------- ----------------- 20.7/37.3 MB 500.6 kB/s eta 0:00:34
#    ---------------------- ----------------- 21.0/37.3 MB 508.7 kB/s eta 0:00:33
#    ---------------------- ----------------- 21.2/37.3 MB 514.7 kB/s eta 0:00:32
#    ----------------------- ---------------- 21.5/37.3 MB 521.0 kB/s eta 0:00:31
#    ----------------------- ---------------- 22.0/37.3 MB 534.0 kB/s eta 0:00:29
#    ------------------------ --------------- 22.5/37.3 MB 552.9 kB/s eta 0:00:27
#    ------------------------ --------------- 22.8/37.3 MB 558.7 kB/s eta 0:00:26
#    ------------------------ --------------- 23.1/37.3 MB 563.8 kB/s eta 0:00:26
#    ------------------------- -------------- 23.3/37.3 MB 569.3 kB/s eta 0:00:25
#    ------------------------- -------------- 23.6/37.3 MB 576.0 kB/s eta 0:00:24
#    ------------------------- -------------- 23.9/37.3 MB 581.6 kB/s eta 0:00:24
#    ------------------------- -------------- 23.9/37.3 MB 581.6 kB/s eta 0:00:24
#    ------------------------- -------------- 24.1/37.3 MB 582.0 kB/s eta 0:00:23
#    ------------------------- -------------- 24.1/37.3 MB 582.0 kB/s eta 0:00:23
#    -------------------------- ------------- 24.4/37.3 MB 591.1 kB/s eta 0:00:22
#    -------------------------- ------------- 24.6/37.3 MB 595.5 kB/s eta 0:00:22
#    -------------------------- ------------- 24.9/37.3 MB 600.6 kB/s eta 0:00:21
#    --------------------------- ------------ 25.4/37.3 MB 611.9 kB/s eta 0:00:20
#    --------------------------- ------------ 25.7/37.3 MB 617.4 kB/s eta 0:00:19
#    --------------------------- ------------ 26.0/37.3 MB 623.0 kB/s eta 0:00:19
#    ---------------------------- ----------- 26.5/37.3 MB 633.0 kB/s eta 0:00:18
#    ---------------------------- ----------- 26.7/37.3 MB 639.4 kB/s eta 0:00:17
#    ----------------------------- ---------- 27.3/37.3 MB 647.9 kB/s eta 0:00:16
#    ----------------------------- ---------- 27.5/37.3 MB 650.1 kB/s eta 0:00:16
#    ----------------------------- ---------- 27.8/37.3 MB 657.8 kB/s eta 0:00:15
#    ------------------------------ --------- 28.0/37.3 MB 661.5 kB/s eta 0:00:14
#    ------------------------------ --------- 28.3/37.3 MB 664.7 kB/s eta 0:00:14
#    ------------------------------ --------- 28.3/37.3 MB 664.7 kB/s eta 0:00:14
#    ------------------------------ --------- 28.6/37.3 MB 685.8 kB/s eta 0:00:13
#    ------------------------------ --------- 28.6/37.3 MB 685.8 kB/s eta 0:00:13
#    ------------------------------ --------- 28.6/37.3 MB 685.8 kB/s eta 0:00:13
#    ------------------------------ --------- 28.8/37.3 MB 682.8 kB/s eta 0:00:13
#    ------------------------------ --------- 28.8/37.3 MB 682.8 kB/s eta 0:00:13
#    ------------------------------ --------- 28.8/37.3 MB 682.8 kB/s eta 0:00:13
#    ------------------------------- -------- 29.1/37.3 MB 689.7 kB/s eta 0:00:12
#    ------------------------------- -------- 29.1/37.3 MB 689.7 kB/s eta 0:00:12
#    ------------------------------- -------- 29.4/37.3 MB 685.8 kB/s eta 0:00:12
#    ------------------------------- -------- 29.4/37.3 MB 685.8 kB/s eta 0:00:12
#    ------------------------------- -------- 29.4/37.3 MB 685.8 kB/s eta 0:00:12
#    ------------------------------- -------- 29.6/37.3 MB 685.5 kB/s eta 0:00:12
#    ------------------------------- -------- 29.6/37.3 MB 685.5 kB/s eta 0:00:12
#    ------------------------------- -------- 29.6/37.3 MB 685.5 kB/s eta 0:00:12
#    -------------------------------- ------- 29.9/37.3 MB 691.2 kB/s eta 0:00:11
#    -------------------------------- ------- 29.9/37.3 MB 691.2 kB/s eta 0:00:11
#    -------------------------------- ------- 30.1/37.3 MB 691.3 kB/s eta 0:00:11
#    -------------------------------- ------- 30.1/37.3 MB 691.3 kB/s eta 0:00:11
#    -------------------------------- ------- 30.1/37.3 MB 691.3 kB/s eta 0:00:11
#    -------------------------------- ------- 30.4/37.3 MB 702.0 kB/s eta 0:00:10
#    -------------------------------- ------- 30.7/37.3 MB 703.4 kB/s eta 0:00:10
#    --------------------------------- ------ 30.9/37.3 MB 709.2 kB/s eta 0:00:09
#    --------------------------------- ------ 31.2/37.3 MB 713.8 kB/s eta 0:00:09
#    --------------------------------- ------ 31.5/37.3 MB 718.8 kB/s eta 0:00:09
#    ---------------------------------- ----- 32.0/37.3 MB 730.2 kB/s eta 0:00:08
#    ---------------------------------- ----- 32.5/37.3 MB 753.4 kB/s eta 0:00:07
#    ----------------------------------- ---- 33.0/37.3 MB 765.4 kB/s eta 0:00:06
#    ----------------------------------- ---- 33.3/37.3 MB 769.6 kB/s eta 0:00:06
#    ----------------------------------- ---- 33.6/37.3 MB 773.7 kB/s eta 0:00:05
#    ------------------------------------ --- 33.8/37.3 MB 777.9 kB/s eta 0:00:05
#    ------------------------------------ --- 34.1/37.3 MB 794.7 kB/s eta 0:00:05
#    ------------------------------------ --- 34.3/37.3 MB 795.3 kB/s eta 0:00:04
#    ------------------------------------- -- 34.6/37.3 MB 798.3 kB/s eta 0:00:04
#    ------------------------------------- -- 34.9/37.3 MB 808.2 kB/s eta 0:00:04
#    ------------------------------------- -- 35.1/37.3 MB 812.8 kB/s eta 0:00:03
#    -------------------------------------- - 35.7/37.3 MB 823.3 kB/s eta 0:00:02
#    -------------------------------------- - 35.9/37.3 MB 831.6 kB/s eta 0:00:02
#    ---------------------------------------  36.4/37.3 MB 840.7 kB/s eta 0:00:02
#    ---------------------------------------  36.4/37.3 MB 840.7 kB/s eta 0:00:02
#    ---------------------------------------  36.7/37.3 MB 845.7 kB/s eta 0:00:01
#    ---------------------------------------  37.0/37.3 MB 864.7 kB/s eta 0:00:01
#    ---------------------------------------- 37.3/37.3 MB 866.7 kB/s  0:00:59
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, scipy, mesa
#
#    ---------------------------------------- 0/3 [tqdm]
#    ---------------------------------------- 0/3 [tqdm]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    -------------------------- ------------- 2/3 [mesa]
#    -------------------------- ------------- 2/3 [mesa]
#    -------------------------- ------------- 2/3 [mesa]
#    -------------------------- ------------- 2/3 [mesa]
#    -------------------------- ------------- 2/3 [mesa]
#    ---------------------------------------- 3/3 [mesa]
#
# Successfully installed mesa-3.5.1 scipy-1.17.1 tqdm-4.67.3
# Requirement already satisfied: numpy in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (2.4.4)
# Requirement already satisfied: matplotlib in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from matplotlib) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: pandas in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (3.0.2)
# Requirement already satisfied: numpy>=2.3.3 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from pandas) (2.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from pandas) (2026.1)
# Requirement already satisfied: six>=1.5 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting networkx
#   Downloading networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 48.2 MB/s  0:00:00
# Installing collected packages: networkx
# Successfully installed networkx-3.6.1

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

from SchellingModel import Schelling

# %% [markdown]
# Now we instantiate a model instance: a 10x10 grid, with an 80% change of an agent being placed in each cell, approximately 20% of agents set as minorities, and agents wanting at least 3 similar neighbors.

# %%
model = Schelling(10, 10, 0.7, 0.3, 3)

# %% [markdown]
# We want to run the model until all the agents are happy with where they are. However, there's no guarentee that a given model instantiation will *ever* settle down. So let's run it for either 100 steps or until it stops on its own, whichever comes first:

# %%
while model.running and model.steps < 100:
    model.step()
print(model.steps)  # Show how many steps have actually run
# Out:
# 12

# %% [markdown]
# The model has a DataCollector object, which checks and stores how many agents are happy at the end of each step. It can also generate a pandas DataFrame of the data it has collected:

# %%
model_out = model.datacollector.get_model_vars_dataframe()

# %%
model_out.head()
# Out:
#    happy  Segregated_Agents
# 0      0           0.074627
# 1     37           0.164179
# 2     52           0.253731
# 3     61           0.388060
# 4     63           0.432836

# %% [markdown]
# Finally, we can plot the 'happy' series:

# %%
model_out.happy.plot()
# Out:
# <Axes: >

# %% [markdown]
# For testing purposes, here is a table giving each agent's x and y values at each step.

# %%
x_positions = model.datacollector.get_agent_vars_dataframe()

# %%
x_positions.head()
# Out:
#               x  y
# Step AgentID
# 0.0  1        0  2
#      2        0  3
#      3        0  4
#      4        0  7
#      5        0  8

# %% [markdown]
# # Effect of Homophily on segregation
#
# Now, we can do a parameter sweep to see how segregation changes with homophily.
#
# First, we create a function which takes a model instance and returns what fraction of agents are segregated -- that is, have no neighbors of the opposite type.

# %%
from mesa.batchrunner import batch_run

# %%
def get_segregation(model):
    '''
    Find the % of agents that only have neighbors of their same type.
    '''
    segregated_agents = 0
    for agent in model.agents:
        segregated = True
        for neighbor in model.grid.iter_neighbors(agent.pos, moore=True):
            if neighbor.type != agent.type:
                segregated = False
                break
        if segregated:
            segregated_agents += 1
    return segregated_agents / len(model.agents)

# %% [markdown]
# Now, we set up the batch run, with a dictionary of fixed and changing parameters. Let's hold everything fixed except for Homophily.

# %%
fixed_params = {"height": 10, "width": 10, "density": 0.8, "minority_pc": 0.2} 
variable_parms = {"homophily": range(1,9)}

# %%
# Combine fixed and variable parameters
params = {**fixed_params, **variable_parms}

# Run batch experiment
results = batch_run(
    Schelling,
    parameters=params,
    iterations=10,
    max_steps=200,
    data_collection_period=-1,
    display_progress=True,
)
# Out:
# C:\Users\Kegan\AppData\Local\Temp\ipykernel_58264\4240939805.py:5: DeprecationWarning: The `iterations` keyword argument is deprecated. Use `rng` instead (e.g. `iterations=5` is equivalent to `rng=[None] * 5`). See https://mesa.readthedocs.io/latest/migration_guide.html#batch-run
#   results = batch_run(
#   0%|          | 0/80 [00:00<?, ?it/s]

# %%
import pandas as pd
df = pd.DataFrame(results)
df.head()
# Out:
#    RunId  iteration  Step  height  width  density  minority_pc  homophily  \
# 0      0          0   4.0      10     10      0.8          0.2          1
# 1      0          0   4.0      10     10      0.8          0.2          1
# 2      0          0   4.0      10     10      0.8          0.2          1
# 3      0          0   4.0      10     10      0.8          0.2          1
# 4      0          0   4.0      10     10      0.8          0.2          1
#
#    seed  happy  Segregated_Agents  AgentID  x  y
# 0  None     72           0.208333        1  0  0
# 1  None     72           0.208333        2  0  1
# 2  None     72           0.208333        3  0  3
# 3  None     72           0.208333        4  0  5
# 4  None     72           0.208333        5  0  7

# %%
plt.scatter(df.homophily, df.Segregated_Agents)
plt.grid(True)
