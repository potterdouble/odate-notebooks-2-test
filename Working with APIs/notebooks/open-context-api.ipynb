# %%
# adapted from Tim Sherratt's https://github.com/wragge/ozglam-workbench
# Make the Requests module available
import requests

# %%
# Create a variable called 'api_search_url' and give it a value
api_search_url = ' https://opencontext.org/query/'

# %%
# Headers provide metadata about our request to the Open Context API server
headers = {
    'accept': 'application/json',  # Tells the API we want data in JSON format
    'User-Agent': 'oc-api-client',  # Identifies us as a "safe" client to the API server
}

# %%
# This creates a dictionary called 'params' and sets values for the API's mandatory parameters
params = {
    'q': 'roman' # Search for this keyword -- feel free to change!
}

# %%
# Let's view the updated dictionary
params
# Out:
# {'q': 'roman'}

# %%
# This sends our request to the API and stores the result in a variable called 'response'
response = requests.get(api_search_url, headers=headers, params=params)

# This shows us the url that's sent to the API
print('Here\'s the formatted url that gets sent to the Open Context API:\n{}\n'.format(response.url)) 

# This checks the status code of the response to make sure there were no errors
if response.status_code == requests.codes.ok:
    print('All ok')
elif response.status_code == 403:
    print('There was an authentication error. Did you paste your API above?')
else:
    print('There was a problem. Error code: {}'.format(response.status_code))
    print('Try running this cell again.')
# Out:
# Here's the formatted url that gets sent to the Open Context API:
# https://opencontext.org/query/?q=roman
#
# All ok

# %%
# Get the API's JSON results and make them available as a Python variable called 'data'
data = response.json()

# %%
# Let's prettify the raw JSON data and then display it.

# We're using the Pygments library to add some colour to the output, so we need to import it
import json
from pygments import highlight, lexers, formatters

# This uses Python's JSON module to output the results as nicely indented text
formatted_data = json.dumps(data, indent=2)

# This colours the text
highlighted_data = highlight(formatted_data, lexers.JsonLexer(), formatters.TerminalFormatter())

# And now display the results
print(highlighted_data)
# Out:
# {
#   "@context": [
#     "https://opencontext.org/contexts/search.json",
#     "http://geojson.org/geojson-ld/geojson-context.jsonld"
#   ],
#   "id": "https://opencontext.org/query/?q=roman",
#   "dcmi:modified": "2026-03-24T22:26:21Z",
#   "dcmi:created": "2025-02-17T00:00:00Z",
#   "oai-pmh:earliestDatestamp": "2006-02-28T00:00:00Z",
#   "oc-api:descriptiveness-min": 12.945,
#   "oc-api:descriptiveness-max": 17578.085,
#   "oc-api:human-remains-flagged": true,
#   "allevent-start": "-999999",
#   "allevent-stop": "2015",
#   "oc-api:all-geospatial-feature-counts": [
#     {
#       "total_events_count": 1,
#       "count": 340964
#     }
#   ],
#   "oc-api:all-chronology-range-counts": [
#     {
#       "total_events_count": 1,
#       "count": 333328
#     }
#   ],
#   "totalResults": 342720,
#   "startIndex": 0,
#   "itemsPerPage": 50,
#   "next": "https://opencontext.org/query/?q=roman&rows=50&start=50",
#   "next-json": "https://opencontext.org/query/.json?q=roman&rows=50&start=50",
#   "last": "https://opencontext.org/query/?q=roman&rows=50&start=342700",
#   "last-json": "https://opencontext.org/query/.json?q=roman&rows=50&start=342700",
#   "oc-api:active-sorting": [
#     {
#       "id": "#current-sort-1",
#       "type": "oc-api:sort-interest",
#       "label": "Interest score",
#       "oc-api:sort-order": "descending"
#     }
#   ],
#   "oc-api:has-sorting": [
#     {
#       "id": "https://opencontext.org/query/?q=roman&sort=item--asc",
#       "json": "https://opencontext.org/query/.json?q=roman&sort=item--asc",
#       "type": "oc-api:sort-item",
#       "label": "Item (type, provenance, label)",
#       "oc-api:sort-order": "ascending"
#     },
#     {
#       "id": "https://opencontext.org/query/?q=roman&sort=item--desc",
#       "json": "https://opencontext.org/query/.json?q=roman&sort=item--desc",
#       "type": "oc-api:sort-item",
#       "label": "Item (type, provenance, label)",
#       "oc-api:sort-order": "descending"
#     },
#     {
#       "id": "https://opencontext.org/query/?q=roman&sort=item-class--asc",
#       "json": "https://opencontext.org/query/.json?q=roman&sort=item-class--asc",
#       "type": "oc-api:sort-item-class",
#       "label": "General category",
#       "oc-api:sort-order": "ascending"
#     },
#     {
#       "id": "https://opencontext.org/query/?q=roman&sort=item-class--desc",
#       "json": "https://opencontext.org/query/.json?q=roman&sort=item-class--desc",
#       "type": "oc-api:sort-item-class",
#       "label": "General category",
#       "oc-api:sort-order": "descending"
#     },
#     {
#       "id": "https://opencontext.org/query/?q=roman&sort=project--asc",
#       "json": "https://opencontext.org/query/.json?q=roman&sort=project--asc",
#       "type": "oc-api:sort-project",
#       "label": "Project",
#       "oc-api:sort-order": "ascending"
#     },
#     {
#       "id": "https://opencontext.org/query/?q=roman&sort=project--desc",
#       "json": "https://opencontext.org/query/.json?q=roman&sort=project--desc",
#       "type": "oc-api:sort-project",
#       "label": "Project",
#       "oc-api:sort-order": "descending"
#     },
#     {
#       "id": "https://opencontext.org/query/?q=roman&sort=updated--asc",
#       "json": "https://opencontext.org/query/.json?q=roman&sort=updated--asc",
#       "type": "oc-api:sort-updated",
#       "label": "Updated",
#       "oc-api:sort-order": "ascending"
#     },
#     {
#       "id": "https://opencontext.org/query/?q=roman&sort=updated--desc",
#       "json": "https://opencontext.org/query/.json?q=roman&sort=updated--desc",
#       "type": "oc-api:sort-updated",
#       "label": "Updated",
#       "oc-api:sort-order": "descending"
#     },
#     {
#       "id": "https://opencontext.org/query/?q=roman&sort=context--asc",
#       "json": "https://opencontext.org/query/.json?q=roman&sort=context--asc",
#       "type": "oc-api:sort-context",
#       "label": "Item Context",
#       "oc-api:sort-order": "ascending"
#     },
#     {
#       "id": "https://opencontext.org/query/?q=roman&sort=context--desc",
#       "json": "https://opencontext.org/query/.json?q=roman&sort=context--desc",
#       "type": "oc-api:sort-context",
#       "label": "Item Context",
#       "oc-api:sort-order": "descending"
#     }
#   ],
#   "oc-api:active-filters": [
#     {
#       "id": "#filter-1",
#       "oc-api:filter": "Current Text Search Filter",
#       "label": "Search Term(s): 'roman'",
#       "oc-api:remove": "https://opencontext.org/query/",
#       "oc-api:remove-json": "https://opencontext.org/query/.json"
#     }
#   ],
#   "oc-api:has-text-search": [
#     {
#       "id": "#textfield-keyword-search",
#       "label": "Current Text Search Filter",
#       "oc-api:search-term": "roman",
#       "oc-api:template": "https://opencontext.org/query/?q=%7Bsearch_term%7D",
#       "oc-api:template-json": "https://opencontext.org/query/.json?q=%7Bsearch_term%7D"
#     }
#   ],
#   "oc-api:has-event-time-ranges": [
#     {
#       "id": "https://opencontext.org/query/?allevent-chronotile=000101001000&allevent-start=-801223.0&allevent-stop=2000.0&q=roman",
#       "json": "https://opencontext.org/query/.json?allevent-chronotile=000101001000&allevent-start=-801223.0&allevent-stop=2000.0&q=roman",
#       "count": 1,
#       "category": "oc-gen:general-time-space",
#       "start": "-801222",
#       "stop": "2000",
#       "properties": {
#         "early bce/ce": -801223.0,
#         "late bce/ce": 2000.0
#       }
#     },
#     {
#       "id": "https://opencontext.org/query/?allevent-chronotile=000000100201&allevent-start=-81008.0&allevent-stop=-7766.0&q=roman",
#       "json": "https://opencontext.org/query/.json?allevent-chronotile=000000100201&allevent-start=-81008.0&allevent-stop=-7766.0&q=roman",
#       "count": 1,
#       "category": "oc-gen:general-time-space",
#       "start": "-81007",
#       "stop": "-7765",
#       "properties": {
#         "early bce/ce": -81008.0,
#         "late bce/ce": -7766.0
#       }
#     },
#     {
#       "id": "https://opencontext.org/query/?allevent-chronotile=000000012223&allevent-start=-41945.0&allevent-stop=-34621.0&q=roman",
#       "json": "https://opencontext.org/query/.json?allevent-chronotile=000000012223&allevent-start=-41945.0&allevent-stop=-34621.0&q=roman",
#       "count": 1,
#       "category": "oc-gen:general-time-space",
#       "start": "-41944",
#       "stop": "-34620",
#       "properties": {
#         "early bce/ce": -41945.0,
#         "late bce/ce": -34621.0
#       }
#     },
#     {
#       "id": "https://opencontext.org/query/?allevent-chronotile=000000012220&allevent-start=-39504.0&allevent-stop=-32180.0&q=roman",
#       "json": "https://opencontext.org/query/.json?allevent-chronotile=000000012220&allevent-start=-39504.0&allevent-stop=-32180.0&q=roman",
#       "count": 4,
#       "category": "oc-gen:general-time-space",
#       "start": "-39503",
#       "stop": "-32179",
#       "properties": {
#         "early bce/ce": -39504.0,
#         "late bce/ce": -32180.0
#       }
#     },
#     {
#       "id": "https://opencontext.org/query/?allevent-chronotile=000000012222&allevent-start=-39504.0&allevent-stop=-34621.0&q=roman",
#       "json": "https://opencontext.org/query/.json?allevent-chronotile=000000012222&allevent-start=-39504.0&allevent-stop=-34621.0&q=roman",
#       "count": 1,
#       "category": "oc-gen:general-time-space",
#       "start": "-39503",
#       "stop": "-34620",
#       "properties": {
#         "early bce/ce": -39504.0,
#         "late bce/ce": -34621.0
#       }
#     },
#     {
#       "id": "https://opencontext.org/query/?allevent-chronotile=000000003312&allevent-start=-34621.0&allevent-stop=-29738.0&q=roman",
#       "json": "https://opencontext.org/query/.json?allevent-chronotile=000000003312&allevent-start=-34621.0&allevent-stop=-29738.0&q=roman",
#       "count": 2,
#       "category": "oc-gen:general-time-space",
#       "start": "-34620",
#       "stop": "-29737",
#       "properties": {
#         "early bce/ce": -34621.0,
#         "late bce/ce": -29738.0
#       }
#     },
#     {
#       "id": "https://opencontext.org/query/?allevent-chronotile=000000003303&allevent-start=-32180.0&allevent-stop=-29738.0&q=roman",
#       "json": "https://opencontext.org/query/.json?allevent-chronotile=000000003303&allevent-start=-32180.0&allevent-stop=-29738.0&q=roman",
#       "count": 2,
#       "category": "oc-gen:general-time-space",
#       "start": "-32179",
#       "stop": "-29737",
#       "properties": {
#         "early bce/ce": -32180.0,
#         "late bce/ce": -29738.0
#       }
#     },
#     {
#       "id": "https://opencontext.org/query/?allevent-chronotile=000000003120&allevent-start=-29738.0&allevent-stop=-22414.0&q=roman",
#       "json": "https://opencontext.org/query/.json?allevent-chronotile=000000003120&allevent-start=-29738.0&allevent-stop=-22414.0&q=roman",
#       "count": 1,
#       "category": "oc-gen:general-time-space",
#       "start": "-29737",
#       "stop": "-22413",
#       "properties": {
#         "early bce/ce": -29738.0,
#         "late bce/ce": -22414.0
#       }
#     },
#     {
#       "id": "https://opencontext.org/query/?allevent-chronotile=000000003300&allevent-start=-29738.0&allevent-stop=-27297.0&q=roman",
#       "json": "https://opencontext.org/query/.json?allevent-chronotile=000000003300&allevent-start=-29738.0&allevent-stop=-27297.0&q=roman",
#       "count": 1,
#       "category": "oc-gen:general-time-space",
#       "start": "-29737",
#       "stop": "-27296",
#       "properties": {
#         "early bce/ce": -29738.0,
#         "late bce/ce": -27297.0
#       }
#     },
#     {
#       "id": "https://opencontext.org/query/?allevent-chronotile=000000003031&allevent-start=-27297.0&allevent-stop=-22414.0&q=roman",
#       "json": "https://opencontext.org/query/.json?allevent-chronotile=000000003031&allevent-start=-27297.0&allevent-stop=-22414.0&q=roman",
#       "count": 2,
#       "category": "oc-gen:general-time-space",
#       "start": "-27296",
#       "stop": "-22413",
#       "properties": {
#         "early bce/ce": -27297.0,
#         "late bce/ce": -22414.0
#       }
#     },
#     {
#       "id": "https://opencontext.org/query/?allevent-chronotile=000000001222&allevent-start=-19973.0&allevent-stop=-15090.0&q=roman",
#       "json": "https://opencontext.org/query/.json?allevent-chronotile=000000001222&allevent-start=-19973.0&allevent-stop=-15090.0&q=roman",
#       "count": 2,
#       "category": "oc-gen:general-time-space",
#       "start": "-19972",
#       "stop": "-15089",
#       "properties": {
#         "early bce/ce": -19973.0,
#         "late bce/ce": -15090.0
#       }
#     },
#     {
#       "id": "https://opencontext.org/query/?allevent-chronotile=000000003000&allevent-start=-19973.0&allevent-stop=-17531.0&q=roman",
#       "json": "https://opencontext.org/query/.json?allevent-chronotile=000000003000&allevent-start=-19973.0&allevent-stop=-17531.0&q=roman",
#       "count": 1,
#       "category": "oc-gen:general-time-space",
#       "start": "-19972",
#       "stop": "-17530",
#       "properties": {
#         "early bce/ce": -19973.0,
#         "late bce/ce": -17531.0
#       }
#     },
#     {
#       "id": "https://opencontext.org/query/?allevent-chronotile=000000000313&allevent-start=-17531.0&allevent-stop=-10207.0&q=roman",
#       "json": "https://opencontext.org/query/.json?allevent-chronotile=000000000313&allevent-start=-17531.0&allevent-stop=-10207.0&q=roman",
#       "count": 1,
#       "category": "oc-gen:general-time-space",
#       "start": "-17530",
#       "stop": "-10206",
#       "properties": {
#         "early bce/ce": -17531.0,
#         "late bce/ce": -10207.0
#       }
#     },
#     {
#       "id": "https://opencontext.org/query/?allevent-chronotile=000000000333&allevent-start=-17531.0&allevent-stop=-15090.0&q=roman",
#       "json": "https://opencontext.org/query/.json?allevent-chronotile=000000000333&allevent-start=-17531.0&allevent-stop=-15090.0&q=roman",
#       "count": 2,
#       "category": "oc-gen:general-time-space",
#       "start": "-17530",
#       "stop": "-15089",
#       "properties": {
#         "early bce/ce": -17531.0,
#         "late bce/ce": -15090.0
#       }
#     },
#     {
#       "id": "https://opencontext.org/query/?allevent-chronotile=000000000110&allevent-start=-15090.0&allevent-stop=2000.0&q=roman",
#       "json": "https://opencontext.org/query/.json?allevent-chronotile=000000000110&allevent-start=-15090.0&allevent-stop=2000.0&q=roman",
#       "count": 1,
#       "category": "oc-gen:general-time-space",
#       "start": "-15089",
#       "stop": "2000",
#       "properties": {
#         "early bce/ce": -15090.0,
#         "late bce/ce": 2000.0
#       }
#     },
#     {
#       "id": "https://opencontext.org/query/?allevent-chronotile=000000000310&allevent-start=-15090.0&allevent-stop=-7766.0&q=roman",
#       "json": "https://opencontext.org/query/.json?allevent-chronotile=000000000310&allevent-start=-15090.0&allevent-stop=-7766.0&q=roman",
#       "count": 1,
#       "category": "oc-gen:general-time-space",
#       "start": "-15089",
#       "stop": "-7765",
#       "properties": {
#         "early bce/ce": -15090.0,
#         "late bce/ce": -7766.0
#       }
#     },
#     {
#       "id": "https://opencontext.org/query/?allevent-chronotile=000000000312&allevent-start=-15090.0&allevent-stop=-10207.0&q=roman",
#       "json": "https://opencontext.org/query/.json?allevent-chronotile=000000000312&allevent-start=-15090.0&allevent-stop=-10207.0&q=roman",
#       "count": 6,
#       "category": "oc-gen:general-time-space",
#       "start": "-15089",
#       "stop": "-10206",
#       "properties": {
#         "early bce/ce": -15090.0,
#         "late bce/ce": -10207.0
#       }
#     },
#     {
#       "id": "https://opencontext.org/query/?allevent-chronotile=000000000330&allevent-start=-15090.0&allevent-stop=-12648.0&q=roman",
#       "json": "https://opencontext.org/query/.json?allevent-chronotile=000000000330&allevent-start=-15090.0&allevent-stop=-12648.0&q=roman",
#       "count": 4,
#       "category": "oc-gen:general-time-space",
#       "start": "-15089",
#       "stop": "-12647",
#       "properties": {
#         "early bce/ce": -15090.0,
#         "late bce/ce": -12648.0
#       }
#     },
#     {
#       "id": "https://opencontext.org/query/?allevent-chronotile=000000000303&allevent-start=-12648.0&allevent-stop=-10207.0&q=roman",
#       "json": "https://opencontext.org/query/.json?allevent-chronotile=000000000303&allevent-start=-12648.0&allevent-stop=-10207.0&q=roman",
#       "count": 3,
#       "category": "oc-gen:general-time-space",
#       "start": "-12647",
#       "stop": "-10206",
#       "properties": {
#         "early bce/ce": -12648.0,
#         "late bce/ce": -10207.0
#       }
#     },
#     {
#       "id": "https://opencontext.org/query/?allevent-chronotile=000000000100&allevent-start=-10207.0&allevent-stop=2000.0&q=roman",
#       "json": "https://opencontext.org/query/.json?allevent-chronotile=000000000100&allevent-start=-10207.0&allevent-stop=2000.0&q=roman",
#       "count": 43,
#       "category": "oc-gen:general-time-space",
#       "start": "-10206",
#       "stop": "2000",
#       "properties": {
#         "early bce/ce": -10207.0,
#         "late bce/ce": 2000.0
#       }
#     },
#     {
#       "id": "https://opencontext.org/query/?allevent-chronotile=000000000102&allevent-start=-10207.0&allevent-stop=-441.0&q=roman",
#       "json": "https://opencontext.org/query/.json?allevent-chronotile=000000000102&allevent-start=-10207.0&allevent-stop=-441.0&q=roman",
#       "count": 1,
#       "category": "oc-gen:general-time-space",
#       "start": "-10206",
#       "stop": "-0440",
#       "properties": {
#         "early bce/ce": -10207.0,
#         "late bce/ce": -441.0
#       }
#     },
#     {
#       "id": "https://opencontext.org/query/?allevent-chronotile=000000000122&allevent-start=-10207.0&allevent-stop=-5324.0&q=roman",
#       "json": "https://opencontext.org/query/.json?allevent-chronotile=000000000122&allevent-start=-10207.0&allevent-stop=-5324.0&q=roman",
#       "count": 2,
#       "category": "oc-gen:general-time-space",
#       "start": "-10206",
#       "stop": "-5323",
#       "properties": {
#         "early bce/ce": -10207.0,
#         "late bce/ce": -5324.0
#       }
#     },
#     {
#       "id": "https://opencontext.org/query/?allevent-chronotile=000000000300&allevent-start=-10207.0&allevent-stop=-7766.0&q=roman",
#       "json": "https://opencontext.org/query/.json?allevent-chronotile=000000000300&allevent-start=-10207.0&allevent-stop=-7766.0&q=roman",
#       "count": 2,
#       "category": "oc-gen:general-time-space",
#       "start": "-10206",
#       "stop": "-7765",
#       "properties": {
#         "early bce/ce": -10207.0,
#         "late bce/ce": -7766.0
#       }
#     },
#     {
#       "id": "https://opencontext.org/query/?allevent-chronotile=000000000011&allevent-start=-7766.0&allevent-stop=2000.0&q=roman",
#       "json": "https://opencontext.org/query/.json?allevent-chronotile=000000000011&allevent-start=-7766.0&allevent-stop=2000.0&q=roman",
#       "count": 25,
#       "category": "oc-gen:general-time-space",
#       "start": "-7765",
#       "stop": "2000",
#       "properties": {
#         "early bce/ce": -7766.0,
#         "late bce/ce": 2000.0
#       }
#     },
#     {
#       "id": "https://opencontext.org/query/?allevent-chronotile=000000000013&allevent-start=-7766.0&allevent-stop=-441.0&q=roman",
#       "json": "https://opencontext.org/query/.json?allevent-chronotile=000000000013&allevent-start=-7766.0&allevent-stop=-441.0&q=roman",
#       "count": 2,
#       "category": "oc-gen:general-time-space",
#       "start": "-7765",
#       "stop": "-0440",
#       "properties": {
#         "early bce/ce": -7766.0,
#         "late bce/ce": -441.0
#       }
#     },
#     {
#       "id": "https://opencontext.org/query/?allevent-chronotile=000000000031&allevent-start=-7766.0&allevent-stop=-2883.0&q=roman",
#       "json": "https://opencontext.org/query/.json?allevent-chronotile=000000000031&allevent-start=-7766.0&allevent-stop=-2883.0&q=roman",
#       "count": 4,
#       "category": "oc-gen:general-time-space",
#       "start": "-7765",
#       "stop": "-2882",
#       "properties": {
#         "early bce/ce": -7766.0,
#         "late bce/ce": -2883.0
#       }
#     },
#     {
#       "id": "https://opencontext.org/query/?allevent-chronotile=000000000033&allevent-start=-7766.0&allevent-stop=-5324.0&q=roman",
#       "json": "https://opencontext.org/query/.json?allevent-chronotile=000000000033&allevent-start=-7766.0&allevent-stop=-5324.0&q=roman",
#       "count": 143,
#       "category": "oc-gen:general-time-space",
#       "start": "-7765",
#       "stop": "-5323",
#       "properties": {
#         "early bce/ce": -7766.0,
#         "late bce/ce": -5324.0
#       }
#     },
#     {
#       "id": "https://opencontext.org/query/?allevent-chronotile=000000000010&allevent-start=-5324.0&allevent-stop=2000.0&q=roman",
#       "json": "https://opencontext.org/query/.json?allevent-chronotile=000000000010&allevent-start=-5324.0&allevent-stop=2000.0&q=roman",
#       "count": 365,
#       "category": "oc-gen:general-time-space",
#       "start": "-5323",
#       "stop": "2000",
#       "properties": {
#         "early bce/ce": -5324.0,
#         "late bce/ce": 2000.0
#       }
#     },
#     {
#       "id": "https://opencontext.org/query/?allevent-chronotile=000000000012&allevent-start=-5324.0&allevent-stop=-441.0&q=roman",
#       "json": "https://opencontext.org/query/.json?allevent-chronotile=000000000012&allevent-start=-5324.0&allevent-stop=-441.0&q=roman",
#       "count": 157,
#       "category": "oc-gen:general-time-space",
#       "start": "-5323",
#       "stop": "-0440",
#       "properties": {
#         "early bce/ce": -5324.0,
#         "late bce/ce": -441.0
#       }
#     },
#     {
#       "id": "https://opencontext.org/query/?allevent-chronotile=000000000030&allevent-start=-5324.0&allevent-stop=-2883.0&q=roman",
#       "json": "https://opencontext.org/query/.json?allevent-chronotile=000000000030&allevent-start=-5324.0&allevent-stop=-2883.0&q=roman",
#       "count": 32,
#       "category": "oc-gen:general-time-space",
#       "start": "-5323",
#       "stop": "-2882",
#       "properties": {
#         "early bce/ce": -5324.0,
#         "late bce/ce": -2883.0
#       }
#     },
#     {
#       "id": "https://opencontext.org/query/?allevent-chronotile=000000000001&allevent-start=-2883.0&allevent-stop=2000.0&q=roman",
#       "json": "https://opencontext.org/query/.json?allevent-chronotile=000000000001&allevent-start=-2883.0&allevent-stop=2000.0&q=roman",
#       "count": 14273,
#       "category": "oc-gen:general-time-space",
#       "start": "-2882",
#       "stop": "2000",
#       "properties": {
#         "early bce/ce": -2883.0,
#         "late bce/ce": 2000.0
#       }
#     },
#     {
#       "id": "https://opencontext.org/query/?allevent-chronotile=000000000003&allevent-start=-2883.0&allevent-stop=-441.0&q=roman",
#       "json": "https://opencontext.org/query/.json?allevent-chronotile=000000000003&allevent-start=-2883.0&allevent-stop=-441.0&q=roman",
#       "count": 97568,
#       "category": "oc-gen:general-time-space",
#       "start": "-2882",
#       "stop": "-0440",
#       "properties": {
#         "early bce/ce": -2883.0,
#         "late bce/ce": -441.0
#       }
#     },
#     {
#       "id": "https://opencontext.org/query/?allevent-chronotile=000000000000&allevent-start=-441.0&allevent-stop=2000.0&q=roman",
#       "json": "https://opencontext.org/query/.json?allevent-chronotile=000000000000&allevent-start=-441.0&allevent-stop=2000.0&q=roman",
#       "count": 219948,
#       "category": "oc-gen:general-time-space",
#       "start": "-0440",
#       "stop": "2000",
#       "properties": {
#         "early bce/ce": -441.0,
#         "late bce/ce": 2000.0
#       }
#     }
#   ],
#   "oc-api:has-facets": [
#     {
#       "id": "#facet-context",
#       "rdfs:isDefinedBy": "oc-api:facet-context",
#       "label": "Context",
#       "type": "oc-api:facet-context",
#       "oc-api:has-id-options": [
#         {
#           "id": "https://opencontext.org/query/Asia?q=roman",
#           "json": "https://opencontext.org/query/Asia.json?q=roman",
#           "rdfs:isDefinedBy": "https://opencontext.org/subjects/a6c5488c-98de-4e5a-9654-c1a2be698840",
#           "slug": "oc-asia",
#           "label": "Asia",
#           "count": 192168
#         },
#         {
#           "id": "https://opencontext.org/query/Europe?q=roman",
#           "json": "https://opencontext.org/query/Europe.json?q=roman",
#           "rdfs:isDefinedBy": "https://opencontext.org/subjects/6cfc6541-b741-44c4-b9d1-d8d9601c5548",
#           "slug": "oc-europe",
#           "label": "Europe",
#           "count": 148502
#         },
#         {
#           "id": "https://opencontext.org/query/Africa?q=roman",
#           "json": "https://opencontext.org/query/Africa.json?q=roman",
#           "rdfs:isDefinedBy": "https://opencontext.org/subjects/2334627d-5db7-4ff8-b61c-49f51aaaf9f8",
#           "slug": "oc-africa",
#           "label": "Africa",
#           "count": 124
#         },
#         {
#           "id": "https://opencontext.org/query/Americas?q=roman",
#           "json": "https://opencontext.org/query/Americas.json?q=roman",
#           "rdfs:isDefinedBy": "https://opencontext.org/subjects/3b59e5d6-e136-407d-9cab-e460f4fbc184",
#           "slug": "oc-americas",
#           "label": "Americas",
#           "count": 42
#         },
#         {
#           "id": "https://opencontext.org/query/Off+World?q=roman",
#           "json": "https://opencontext.org/query/Off+World.json?q=roman",
#           "rdfs:isDefinedBy": "https://opencontext.org/subjects/572c2821-d2a8-4986-8537-5e37a64c7361",
#           "slug": "oc-off-world-root",
#           "label": "Off World",
#           "count": 1
#         }
#       ]
#     },
#     {
#       "id": "#facet-prop-ld",
#       "rdfs:isDefinedBy": "oc-api:facet-prop-ld",
#       "label": "Descriptions (Common Standards)",
#       "type": "oc-api:facet-prop",
#       "oc-api:has-id-options": [
#         {
#           "id": "https://opencontext.org/query/?prop=dc-terms-license&q=roman",
#           "json": "https://opencontext.org/query/.json?prop=dc-terms-license&q=roman",
#           "rdfs:isDefinedBy": "https://purl.org/dc/terms/license",
#           "slug": "dc-terms-license",
#           "label": "License",
#           "count": 342720
#         },
#         {
#           "id": "https://opencontext.org/query/?prop=dc-terms-creator&q=roman",
#           "json": "https://opencontext.org/query/.json?prop=dc-terms-creator&q=roman",
#           "rdfs:isDefinedBy": "https://purl.org/dc/terms/creator",
#           "slug": "dc-terms-creator",
#           "label": "Creator",
#           "count": 342680
#         },
#         {
#           "id": "https://opencontext.org/query/?prop=dc-terms-subject&q=roman",
#           "json": "https://opencontext.org/query/.json?prop=dc-terms-subject&q=roman",
#           "rdfs:isDefinedBy": "https://purl.org/dc/terms/subject",
#           "slug": "dc-terms-subject",
#           "label": "Subject",
#           "skos:altLabel": "Subject Metadata",
#           "count": 314665
#         },
#         {
#           "id": "https://opencontext.org/query/?prop=dc-terms-coverage&q=roman",
#           "json": "https://opencontext.org/query/.json?prop=dc-terms-coverage&q=roman",
#           "rdfs:isDefinedBy": "https://purl.org/dc/terms/coverage",
#           "slug": "dc-terms-coverage",
#           "label": "Coverage",
#           "skos:altLabel": "Coverage (Period) Metadata",
#           "count": 249671
#         },
#         {
#           "id": "https://opencontext.org/query/?prop=dc-terms-spatial&q=roman",
#           "json": "https://opencontext.org/query/.json?prop=dc-terms-spatial&q=roman",
#           "rdfs:isDefinedBy": "https://purl.org/dc/terms/spatial",
#           "slug": "dc-terms-spatial",
#           "label": "Spatial Coverage",
#           "skos:altLabel": "Spatial Metadata",
#           "count": 207588
#         },
#         {
#           "id": "https://opencontext.org/query/?prop=dc-terms-has-part&q=roman",
#           "json": "https://opencontext.org/query/.json?prop=dc-terms-has-part&q=roman",
#           "rdfs:isDefinedBy": "https://purl.org/dc/terms/hasPart",
#           "slug": "dc-terms-has-part",
#           "label": "Has Part",
#           "count": 205116
#         },
#         {
#           "id": "https://opencontext.org/query/?prop=dc-terms-temporal&q=roman",
#           "json": "https://opencontext.org/query/.json?prop=dc-terms-temporal&q=roman",
#           "rdfs:isDefinedBy": "https://purl.org/dc/terms/temporal",
#           "slug": "dc-terms-temporal",
#           "label": "Temporal Coverage",
#           "count": 159167
#         },
#         {
#           "id": "https://opencontext.org/query/?prop=cidoc-crm-p2-has-type&q=roman",
#           "json": "https://opencontext.org/query/.json?prop=cidoc-crm-p2-has-type&q=roman",
#           "rdfs:isDefinedBy": "https://erlangen-crm.org/current/P2_has_type",
#           "slug": "cidoc-crm-p2-has-type",
#           "label": "Has type",
#           "count": 145775
#         },
#         {
#           "id": "https://opencontext.org/query/?prop=cidoc-crm-p45-consists-of&q=roman",
#           "json": "https://opencontext.org/query/.json?prop=cidoc-crm-p45-consists-of&q=roman",
#           "rdfs:isDefinedBy": "https://erlangen-crm.org/current/P45_consists_of",
#           "slug": "cidoc-crm-p45-consists-of",
#           "label": "Consists of",
#           "count": 139503
#         },
#         {
#           "id": "https://opencontext.org/query/?prop=dc-terms-contributor&q=roman",
#           "json": "https://opencontext.org/query/.json?prop=dc-terms-contributor&q=roman",
#           "rdfs:isDefinedBy": "https://purl.org/dc/terms/contributor",
#           "slug": "dc-terms-contributor",
#           "label": "Contributor",
#           "count": 103142
#         },
#         {
#           "id": "https://opencontext.org/query/?prop=obo-foodon-00001303&q=roman",
#           "json": "https://opencontext.org/query/.json?prop=obo-foodon-00001303&q=roman",
#           "rdfs:isDefinedBy": "http://purl.obolibrary.org/obo/FOODON_00001303",
#           "slug": "obo-foodon-00001303",
#           "label": "Has taxonomic identifier",
#           "count": 38555
#         },
#         {
#           "id": "https://opencontext.org/query/?prop=dc-terms-is-part-of&q=roman",
#           "json": "https://opencontext.org/query/.json?prop=dc-terms-is-part-of&q=roman",
#           "rdfs:isDefinedBy": "https://purl.org/dc/terms/isPartOf",
#           "slug": "dc-terms-is-part-of",
#           "label": "Is Part Of",
#           "count": 12105
#         },
#         {
#           "id": "https://opencontext.org/query/?prop=cidoc-crm-e54-dimension&q=roman",
#           "json": "https://opencontext.org/query/.json?prop=cidoc-crm-e54-dimension&q=roman",
#           "rdfs:isDefinedBy": "https://erlangen-crm.org/current/E54_Dimension",
#           "slug": "cidoc-crm-e54-dimension",
#           "label": "E54 Dimension",
#           "count": 8590
#         },
#         {
#           "id": "https://opencontext.org/query/?prop=obo-pato-0000040&q=roman",
#           "json": "https://opencontext.org/query/.json?prop=obo-pato-0000040&q=roman",
#           "rdfs:isDefinedBy": "http://purl.obolibrary.org/obo/PATO_0000040",
#           "slug": "obo-pato-0000040",
#           "label": "Distance",
#           "count": 8590
#         },
#         {
#           "id": "https://opencontext.org/query/?prop=dc-terms-references&q=roman",
#           "json": "https://opencontext.org/query/.json?prop=dc-terms-references&q=roman",
#           "rdfs:isDefinedBy": "https://purl.org/dc/terms/references",
#           "slug": "dc-terms-references",
#           "label": "References",
#           "count": 4755
#         },
#         {
#           "id": "https://opencontext.org/query/?prop=cidoc-crm-p62-depicts&q=roman",
#           "json": "https://opencontext.org/query/.json?prop=cidoc-crm-p62-depicts&q=roman",
#           "rdfs:isDefinedBy": "https://erlangen-crm.org/current/P62_depicts",
#           "slug": "cidoc-crm-p62-depicts",
#           "label": "Depicts",
#           "count": 257
#         },
#         {
#           "id": "https://opencontext.org/query/?prop=dc-terms-is-referenced-by&q=roman",
#           "json": "https://opencontext.org/query/.json?prop=dc-terms-is-referenced-by&q=roman",
#           "rdfs:isDefinedBy": "https://purl.org/dc/terms/isReferencedBy",
#           "slug": "dc-terms-is-referenced-by",
#           "label": "Is Referenced By",
#           "skos:altLabel": "Is Referenced by Metadata",
#           "count": 112
#         },
#         {
#           "id": "https://opencontext.org/query/?prop=gawd-origin&q=roman",
#           "json": "https://opencontext.org/query/.json?prop=gawd-origin&q=roman",
#           "rdfs:isDefinedBy": "https://gawd.atlantides.org/terms/origin",
#           "slug": "gawd-origin",
#           "label": "Origin place",
#           "count": 109
#         },
#         {
#           "id": "https://opencontext.org/query/?prop=dc-terms-source&q=roman",
#           "json": "https://opencontext.org/query/.json?prop=dc-terms-source&q=roman",
#           "rdfs:isDefinedBy": "https://purl.org/dc/terms/source",
#           "slug": "dc-terms-source",
#           "label": "Source",
#           "count": 33
#         },
#         {
#           "id": "https://opencontext.org/query/?prop=dinaa-00001&q=roman",
#           "json": "https://opencontext.org/query/.json?prop=dinaa-00001&q=roman",
#           "rdfs:isDefinedBy": "https://opencontext.org/vocabularies/dinaa/00001",
#           "slug": "dinaa-00001",
#           "label": "Has period",
#           "count": 6
#         }
#       ],
#       "oc-api:has-text-options": [
#         {
#           "id": "https://opencontext.org/query/?prop=schema-org-text&q=roman",
#           "json": "https://opencontext.org/query/.json?prop=schema-org-text&q=roman",
#           "rdfs:isDefinedBy": "https://schema.org/text",
#           "slug": "schema-org-text",
#           "label": "Text",
#           "count": 12462
#         },
#         {
#           "id": "https://opencontext.org/query/?prop=dc-terms-abstract&q=roman",
#           "json": "https://opencontext.org/query/.json?prop=dc-terms-abstract&q=roman",
#           "rdfs:isDefinedBy": "https://purl.org/dc/terms/abstract",
#           "slug": "dc-terms-abstract",
#           "label": "Abstract",
#           "count": 61
#         },
#         {
#           "id": "https://opencontext.org/query/?prop=dc-terms-description&q=roman",
#           "json": "https://opencontext.org/query/.json?prop=dc-terms-description&q=roman",
#           "rdfs:isDefinedBy": "https://purl.org/dc/terms/description",
#           "slug": "dc-terms-description",
#           "label": "Description",
#           "count": 29
#         },
#         {
#           "id": "https://opencontext.org/query/?prop=dc-terms-references&q=roman",
#           "json": "https://opencontext.org/query/.json?prop=dc-terms-references&q=roman",
#           "rdfs:isDefinedBy": "https://purl.org/dc/terms/references",
#           "slug": "dc-terms-references",
#           "label": "References",
#           "count": 25
#         },
#         {
#           "id": "https://opencontext.org/query/?prop=skos-alt-label&q=roman",
#           "json": "https://opencontext.org/query/.json?prop=skos-alt-label&q=roman",
#           "rdfs:isDefinedBy": "https://www.w3.org/2004/02/skos/core#altLabel",
#           "slug": "skos-alt-label",
#           "label": "Alternative label",
#           "skos:altLabel": "Alt label",
#           "count": 6
#         }
#       ]
#     },
#     {
#       "id": "#facet-project",
#       "rdfs:isDefinedBy": "oc-api:facet-project",
#       "label": "Project or Collection",
#       "type": "oc-api:facet-project",
#       "oc-api:has-id-options": [
#         {
#           "id": "https://opencontext.org/query/?proj=10-petra-great-temple-excavations&q=roman",
#           "json": "https://opencontext.org/query/.json?proj=10-petra-great-temple-excavations&q=roman",
#           "rdfs:isDefinedBy": "https://opencontext.org/projects/a5ddbea2-b3c8-43f9-8151-33343cbdc857",
#           "slug": "10-petra-great-temple-excavations",
#           "label": "Petra Great Temple Excavations",
#           "count": 127524
#         },
#         {
#           "id": "https://opencontext.org/query/?proj=24-murlo&q=roman",
#           "json": "https://opencontext.org/query/.json?proj=24-murlo&q=roman",
#           "rdfs:isDefinedBy": "https://opencontext.org/projects/df043419-f23b-41da-7e4d-ee52af22f92f",
#           "slug": "24-murlo",
#           "label": "Murlo",
#           "count": 100627
#         },
#         {
#           "id": "https://opencontext.org/query/?proj=117-avkat-archaeological-project&q=roman",
#           "json": "https://opencontext.org/query/.json?proj=117-avkat-archaeological-project&q=roman",
#           "rdfs:isDefinedBy": "https://opencontext.org/projects/02b55e8c-e9b1-49e5-8edf-0afeea10e2be",
#           "slug": "117-avkat-archaeological-project",
#           "label": "Avkat Archaeological Project",
#           "count": 51747
#         },
#         {
#           "id": "https://opencontext.org/query/?proj=169-cattle-husbandry-in-the-iron-age-and-roman-britain&q=roman",
#           "json": "https://opencontext.org/query/.json?proj=169-cattle-husbandry-in-the-iron-age-and-roman-britain&q=roman",
#           "rdfs:isDefinedBy": "https://opencontext.org/projects/0c2d10b9-9691-458b-991b-01602195405c",
#           "slug": "169-cattle-husbandry-in-the-iron-age-and-roman-britain",
#           "label": "Cattle husbandry in the Iron Age and Roman Britain",
#           "count": 22031
#         },
#         {
#           "id": "https://opencontext.org/query/?proj=42-pyla-koutsopetria-archaeological-project-i-pedestrian&q=roman",
#           "json": "https://opencontext.org/query/.json?proj=42-pyla-koutsopetria-archaeological-project-i-pedestrian&q=roman",
#           "rdfs:isDefinedBy": "https://opencontext.org/projects/3f6dcd13-a476-488e-ed10-47d25513fcb2",
#           "slug": "42-pyla-koutsopetria-archaeological-project-i-pedestrian",
#           "label": "Pyla-Koutsopetria Archaeological Project I: Pedestrian Survey",
#           "count": 13063
#         },
#         {
#           "id": "https://opencontext.org/query/?proj=14-bade-museum&q=roman",
#           "json": "https://opencontext.org/query/.json?proj=14-bade-museum&q=roman",
#           "rdfs:isDefinedBy": "https://opencontext.org/projects/b4345f6a-f926-4062-144e-3fbc175cc7b6",
#           "slug": "14-bade-museum",
#           "label": "Bade Museum",
#           "count": 6764
#         },
#         {
#           "id": "https://opencontext.org/query/?proj=164-the-eastern-korinthia-archaeological-survey&q=roman",
#           "json": "https://opencontext.org/query/.json?proj=164-the-eastern-korinthia-archaeological-survey&q=roman",
#           "rdfs:isDefinedBy": "https://opencontext.org/projects/bc71c724-eb1e-47d6-9d45-b586ddafdcfe",
#           "slug": "164-the-eastern-korinthia-archaeological-survey",
#           "label": "The Eastern Korinthia Archaeological Survey",
#           "count": 5819
#         },
#         {
#           "id": "https://opencontext.org/query/?proj=112-tel-dor-area-g-report&q=roman",
#           "json": "https://opencontext.org/query/.json?proj=112-tel-dor-area-g-report&q=roman",
#           "rdfs:isDefinedBy": "https://opencontext.org/projects/b028c160-092e-4e2d-9738-a40367ad543b",
#           "slug": "112-tel-dor-area-g-report",
#           "label": "Tel Dor, Area G Report",
#           "count": 3935
#         },
#         {
#           "id": "https://opencontext.org/query/?proj=125-pyla-koutsopetria-archaeological-project-ii-geophysics&q=roman",
#           "json": "https://opencontext.org/query/.json?proj=125-pyla-koutsopetria-archaeological-project-ii-geophysics&q=roman",
#           "rdfs:isDefinedBy": "https://opencontext.org/projects/b9472eec-e622-4838-b6d8-5a2958b9d4d3",
#           "slug": "125-pyla-koutsopetria-archaeological-project-ii-geophysics",
#           "label": "Pyla-Koutsopetria Archaeological Project II: Geophysics and Excavation",
#           "count": 2541
#         },
#         {
#           "id": "https://opencontext.org/query/?proj=177-the-greek-american-excavations-at-koutsongila-kenchrea&q=roman",
#           "json": "https://opencontext.org/query/.json?proj=177-the-greek-american-excavations-at-koutsongila-kenchrea&q=roman",
#           "rdfs:isDefinedBy": "https://opencontext.org/projects/ce8fcc0f-adff-4ece-a1c6-634326ed8a23",
#           "slug": "177-the-greek-american-excavations-at-koutsongila-kenchrea",
#           "label": "The Greek-American Excavations at Koutsongila, Kenchreai",
#           "count": 2475
#         },
#         {
#           "id": "https://opencontext.org/query/?proj=104-the-gabii-project&q=roman",
#           "json": "https://opencontext.org/query/.json?proj=104-the-gabii-project&q=roman",
#           "rdfs:isDefinedBy": "https://opencontext.org/projects/3585b372-8d2d-436c-9a4c-b5c10fce3ccd",
#           "slug": "104-the-gabii-project",
#           "label": "The Gabii Project",
#           "count": 2441
#         },
#         {
#           "id": "https://opencontext.org/query/?proj=11-aegean-archaeomalacology&q=roman",
#           "json": "https://opencontext.org/query/.json?proj=11-aegean-archaeomalacology&q=roman",
#           "rdfs:isDefinedBy": "https://opencontext.org/projects/b1dac335-4dc6-4a57-622e-75bf28ba598d",
#           "slug": "11-aegean-archaeomalacology",
#           "label": "Aegean Archaeomalacology",
#           "count": 976
#         },
#         {
#           "id": "https://opencontext.org/query/?proj=21-rough-cilicia&q=roman",
#           "json": "https://opencontext.org/query/.json?proj=21-rough-cilicia&q=roman",
#           "rdfs:isDefinedBy": "https://opencontext.org/projects/295b5bf4-0f44-4698-80cd-7a39cb6f133d",
#           "slug": "21-rough-cilicia",
#           "label": "Rough Cilicia",
#           "count": 553
#         },
#         {
#           "id": "https://opencontext.org/query/?proj=65-biometrical-database-of-european-aurochs-and-domestic-c&q=roman",
#           "json": "https://opencontext.org/query/.json?proj=65-biometrical-database-of-european-aurochs-and-domestic-c&q=roman",
#           "rdfs:isDefinedBy": "https://opencontext.org/projects/1816a043-92e2-471d-a23d-aac58695d0d3",
#           "slug": "65-biometrical-database-of-european-aurochs-and-domestic-c",
#           "label": "Biometrical Database of European Aurochs and Domestic Cattle",
#           "count": 524
#         },
#         {
#           "id": "https://opencontext.org/query/?proj=174-community-and-identity-in-the-roman-seventh-legion&q=roman",
#           "json": "https://opencontext.org/query/.json?proj=174-community-and-identity-in-the-roman-seventh-legion&q=roman",
#           "rdfs:isDefinedBy": "https://opencontext.org/projects/7a06aecd-8b0e-4f94-b0f9-5c9fb649e003",
#           "slug": "174-community-and-identity-in-the-roman-seventh-legion",
#           "label": "Community and Identity in the Roman Seventh Legion",
#           "count": 380
#         },
#         {
#           "id": "https://opencontext.org/query/?proj=0-madaba-plains-project-umayri&q=roman",
#           "json": "https://opencontext.org/query/.json?proj=0-madaba-plains-project-umayri&q=roman",
#           "rdfs:isDefinedBy": "https://opencontext.org/projects/2015946b-da6d-4a0f-b676-03bee1efad21",
#           "slug": "0-madaba-plains-project-umayri",
#           "label": "Madaba Plains Project-`Umayri",
#           "count": 371
#         },
#         {
#           "id": "https://opencontext.org/query/?proj=197-p3k14c&q=roman",
#           "json": "https://opencontext.org/query/.json?proj=197-p3k14c&q=roman",
#           "rdfs:isDefinedBy": "https://opencontext.org/projects/cdd78c10-e6da-42ef-9829-e792ce55bdd6",
#           "slug": "197-p3k14c",
#           "label": "Cross-referenced p3k14c",
#           "count": 297
#         },
#         {
#           "id": "https://opencontext.org/query/?proj=63-excavations-at-polis&q=roman",
#           "json": "https://opencontext.org/query/.json?proj=63-excavations-at-polis&q=roman",
#           "rdfs:isDefinedBy": "https://opencontext.org/projects/766d9fd5-2175-41e3-b7c9-7eba6777f1f0",
#           "slug": "63-excavations-at-polis",
#           "label": "Excavations at Polis",
#           "count": 138
#         },
#         {
#           "id": "https://opencontext.org/query/?proj=35-catalhoyuk-area-tp-zooarchaeology&q=roman",
#           "json": "https://opencontext.org/query/.json?proj=35-catalhoyuk-area-tp-zooarchaeology&q=roman",
#           "rdfs:isDefinedBy": "https://opencontext.org/projects/02594c48-7497-40d7-11ae-ab942dc513b8",
#           "slug": "35-catalhoyuk-area-tp-zooarchaeology",
#           "label": "\u00c7atalh\u00f6y\u00fck Area TP Zooarchaeology",
#           "count": 123
#         },
#         {
#           "id": "https://opencontext.org/query/?proj=101-arce-sphinx-project-1979-1983-archive&q=roman",
#           "json": "https://opencontext.org/query/.json?proj=101-arce-sphinx-project-1979-1983-archive&q=roman",
#           "rdfs:isDefinedBy": "https://opencontext.org/projects/141e814a-ba2d-4560-879f-80f1afb019e9",
#           "slug": "101-arce-sphinx-project-1979-1983-archive",
#           "label": "ARCE Sphinx Project 1979-1983 Archive",
#           "count": 112
#         },
#         {
#           "id": "https://opencontext.org/query/?proj=184-kahramanmaras-survey&q=roman",
#           "json": "https://opencontext.org/query/.json?proj=184-kahramanmaras-survey&q=roman",
#           "rdfs:isDefinedBy": "https://opencontext.org/projects/ca4f4719-f2a5-4119-99fa-b04573c8929a",
#           "slug": "184-kahramanmaras-survey",
#           "label": "Kahramanmara\u015f Survey",
#           "count": 69
#         },
#         {
#           "id": "https://opencontext.org/query/?proj=116-visualizing-votive-practice-exploring-limestone-and-te&q=roman",
#           "json": "https://opencontext.org/query/.json?proj=116-visualizing-votive-practice-exploring-limestone-and-te&q=roman",
#           "rdfs:isDefinedBy": "https://opencontext.org/projects/a52bd40a-9ac8-4160-a9b0-bd2795079203",
#           "slug": "116-visualizing-votive-practice-exploring-limestone-and-te",
#           "label": "Visualizing Votive Practice: Exploring Limestone and Terracotta Sculpture from Athienou-Malloura through 3D Models",
#           "count": 39
#         },
#         {
#           "id": "https://opencontext.org/query/?proj=20-dhiban-excavation-and-development-project&q=roman",
#           "json": "https://opencontext.org/query/.json?proj=20-dhiban-excavation-and-development-project&q=roman",
#           "rdfs:isDefinedBy": "https://opencontext.org/projects/01d080df-2f6b-4f59-bcf0-87543ac89574",
#           "slug": "20-dhiban-excavation-and-development-project",
#           "label": "Dhiban Excavation and Development Project",
#           "count": 36
#         },
#         {
#           "id": "https://opencontext.org/query/?proj=1-domuztepe-excavations&q=roman",
#           "json": "https://opencontext.org/query/.json?proj=1-domuztepe-excavations&q=roman",
#           "rdfs:isDefinedBy": "https://opencontext.org/projects/e6fb0f7c-6f69-6ca8-683b-8c6d5e98a099",
#           "slug": "1-domuztepe-excavations",
#           "label": "Domuztepe Excavations",
#           "count": 18
#         },
#         {
#           "id": "https://opencontext.org/query/?proj=93-biometry-of-iron-age-ii-and-hellenistic-period-dog-bur&q=roman",
#           "json": "https://opencontext.org/query/.json?proj=93-biometry-of-iron-age-ii-and-hellenistic-period-dog-bur&q=roman",
#           "rdfs:isDefinedBy": "https://opencontext.org/projects/646b7034-07b7-4971-8d89-ebe37dda4cd2",
#           "slug": "93-biometry-of-iron-age-ii-and-hellenistic-period-dog-bur",
#           "label": "Biometry of Iron Age II and Hellenistic Period Dog \u2019Burials\u2019 from Tell Gezer and Other Sites",
#           "count": 14
#         },
#         {
#           "id": "https://opencontext.org/query/?proj=168-early-islamic-mosques-database&q=roman",
#           "json": "https://opencontext.org/query/.json?proj=168-early-islamic-mosques-database&q=roman",
#           "rdfs:isDefinedBy": "https://opencontext.org/projects/95b1ef01-9ccb-4484-b0f2-540f4dc54672",
#           "slug": "168-early-islamic-mosques-database",
#           "label": "Early Islamic Mosques Database",
#           "count": 12
#         },
#         {
#           "id": "https://opencontext.org/query/?proj=22-kenan-tepe&q=roman",
#           "json": "https://opencontext.org/query/.json?proj=22-kenan-tepe&q=roman",
#           "rdfs:isDefinedBy": "https://opencontext.org/projects/3de4cd9c-259e-4c14-9b03-8b10454ba66e",
#           "slug": "22-kenan-tepe",
#           "label": "Kenan Tepe",
#           "count": 10
#         },
#         {
#           "id": "https://opencontext.org/query/?proj=52-digital-index-of-north-american-archaeology-dinaa&q=roman",
#           "json": "https://opencontext.org/query/.json?proj=52-digital-index-of-north-american-archaeology-dinaa&q=roman",
#           "rdfs:isDefinedBy": "https://opencontext.org/projects/416a274c-cf88-4471-3e31-93db825e9e4a",
#           "slug": "52-digital-index-of-north-american-archaeology-dinaa",
#           "label": "Digital Index of North American Archaeology (DINAA)",
#           "count": 6
#         },
#         {
#           "id": "https://opencontext.org/query/?proj=91-historic-fort-snelling&q=roman",
#           "json": "https://opencontext.org/query/.json?proj=91-historic-fort-snelling&q=roman",
#           "rdfs:isDefinedBy": "https://opencontext.org/projects/fab0532a-2953-4f13-aa97-8a9d7e992dbe",
#           "slug": "91-historic-fort-snelling",
#           "label": "Historic Fort Snelling",
#           "count": 6
#         },
#         {
#           "id": "https://opencontext.org/query/?proj=122-trap-digital-archive&q=roman",
#           "json": "https://opencontext.org/query/.json?proj=122-trap-digital-archive&q=roman",
#           "rdfs:isDefinedBy": "https://opencontext.org/projects/24e2aa20-59e6-4d66-948b-50ee245a7cfc",
#           "slug": "122-trap-digital-archive",
#           "label": "TRAP Digital Archive",
#           "count": 4
#         },
#         {
#           "id": "https://opencontext.org/query/?proj=39-ceramics-trade-provenience-and-geology-cyprus-in-the&q=roman",
#           "json": "https://opencontext.org/query/.json?proj=39-ceramics-trade-provenience-and-geology-cyprus-in-the&q=roman",
#           "rdfs:isDefinedBy": "https://opencontext.org/projects/ababd13c-a69f-499e-ca7f-5118f3684e4d",
#           "slug": "39-ceramics-trade-provenience-and-geology-cyprus-in-the",
#           "label": "Ceramics, Trade, Provenience and Geology: Cyprus in the Late Bronze Age",
#           "count": 4
#         },
#         {
#           "id": "https://opencontext.org/query/?proj=99-idalion&q=roman",
#           "json": "https://opencontext.org/query/.json?proj=99-idalion&q=roman",
#           "rdfs:isDefinedBy": "https://opencontext.org/projects/df8e4efd-e06b-4b0b-a056-08b6fd199536",
#           "slug": "99-idalion",
#           "label": "Idalion",
#           "count": 4
#         },
#         {
#           "id": "https://opencontext.org/query/?proj=169-cattle-and-people-interdisciplinary-approaches-to-an-a&q=roman",
# ...
#         "href": "https://opencontext.org/documents/95c9983e-4e78-4964-b3fb-dbe2575e2406",
#         "citation uri": "https://n2t.net/ark:/28722/k2gf13b2h",
#         "project label": "Murlo",
#         "project href": "https://opencontext.org/projects/df043419-f23b-41da-7e4d-ee52af22f92f",
#         "context label": "Europe/Italy/Poggio Civitate/Civitate A/Civitate A 64/2010, ID:620",
#         "context href": "https://opencontext.org/subjects/60f9b8c2-7279-4bf5-9bd1-a0a1c3747017",
#         "early bce/ce": -700.0,
#         "late bce/ce": -535.0,
#         "item category": "Documents",
#         "icon": "https://opencontext.org/static/oc/icons-v2/noun-document-3183378.svg",
#         "published": "2017-10-04T09:38:35Z",
#         "updated": "2025-04-05T04:45:29Z"
#       }
#     },
#     {
#       "id": "#record-43-of-342720",
#       "label": "VT-12 (2016-08-07):309-324; Pottery Tables",
#       "slug": "24-vt-12-2016-08-07309-324-pottery-tables",
#       "rdfs:isDefinedBy": "http://opencontext.org/documents/902b601a-c058-4842-bdc3-2c584047a6e3",
#       "oc-api:descriptiveness": 1526.17,
#       "oc-api:human-remains-related": false,
#       "type": "Feature",
#       "category": "oc-api:geo-record",
#       "geometry": {
#         "id": "#record-geom-43-of-342720",
#         "type": "Point",
#         "coordinates": [
#           11.39100380477329,
#           43.171241771573214
#         ]
#       },
#       "when": {
#         "id": "#record-event-43-of-342720",
#         "event_type": "oc-gen:general-time-space",
#         "type": "Interval",
#         "start": "-0534",
#         "stop": "-0049"
#       },
#       "properties": {
#         "id": "#rec-43-of-342720",
#         "feature-type": "item record",
#         "label": "VT-12 (2016-08-07):309-324; Pottery Tables",
#         "uri": "http://opencontext.org/documents/902b601a-c058-4842-bdc3-2c584047a6e3",
#         "href": "https://opencontext.org/documents/902b601a-c058-4842-bdc3-2c584047a6e3",
#         "citation uri": "https://n2t.net/ark:/28722/k2xw4q66r",
#         "project label": "Murlo",
#         "project href": "https://opencontext.org/projects/df043419-f23b-41da-7e4d-ee52af22f92f",
#         "context label": "Europe/Italy/Vescovado di Murlo/Upper Vescovado/Vescovado 12/2016, ID:720",
#         "context href": "https://opencontext.org/subjects/5870f6a9-dbb0-425d-9c8b-2424a9fa060a",
#         "early bce/ce": -535.0,
#         "late bce/ce": -50.0,
#         "item category": "Documents",
#         "icon": "https://opencontext.org/static/oc/icons-v2/noun-document-3183378.svg",
#         "published": "2017-10-04T16:50:34Z",
#         "updated": "2025-04-05T04:39:10Z"
#       }
#     },
#     {
#       "id": "#record-44-of-342720",
#       "label": "JW I (1968-08-01):129-145; Catalogued Frieze Plaques",
#       "slug": "24-jw-i-1968-08-01129-145-catalogued-frieze-plaques",
#       "rdfs:isDefinedBy": "http://opencontext.org/documents/7e0a16b2-99f7-4fbd-8d09-cbfe3d7ff0e0",
#       "oc-api:descriptiveness": 1501.18,
#       "oc-api:human-remains-related": false,
#       "type": "Feature",
#       "category": "oc-api:geo-record",
#       "geometry": {
#         "id": "#record-geom-44-of-342720",
#         "type": "Point",
#         "coordinates": [
#           11.40071776178953,
#           43.15321366194307
#         ]
#       },
#       "when": {
#         "id": "#record-event-44-of-342720",
#         "event_type": "oc-gen:general-time-space",
#         "type": "Interval",
#         "start": "-0699",
#         "stop": "-0534"
#       },
#       "properties": {
#         "id": "#rec-44-of-342720",
#         "feature-type": "item record",
#         "label": "JW I (1968-08-01):129-145; Catalogued Frieze Plaques",
#         "uri": "http://opencontext.org/documents/7e0a16b2-99f7-4fbd-8d09-cbfe3d7ff0e0",
#         "href": "https://opencontext.org/documents/7e0a16b2-99f7-4fbd-8d09-cbfe3d7ff0e0",
#         "citation uri": "https://n2t.net/ark:/28722/k2nk3nh9f",
#         "project label": "Murlo",
#         "project href": "https://opencontext.org/projects/df043419-f23b-41da-7e4d-ee52af22f92f",
#         "context label": "Europe/Italy/Poggio Civitate/Civitate A/Civitate A 2/1968, ID:485/PC 19680267",
#         "context href": "https://opencontext.org/subjects/20c82eb2-86e1-4dcf-c658-60fa974ab51b",
#         "early bce/ce": -700.0,
#         "late bce/ce": -535.0,
#         "item category": "Documents",
#         "icon": "https://opencontext.org/static/oc/icons-v2/noun-document-3183378.svg",
#         "thumbnail": "https://artiraq.org/static/opencontext/poggio-civitate/thumbs/trenchbookimages/uncropped/JWrightI_145,145.JPG",
#         "published": "2017-10-04T09:58:49Z",
#         "updated": "2025-04-05T03:50:55Z"
#       }
#     },
#     {
#       "id": "#record-45-of-342720",
#       "label": "AMA/DBB I (2008-08-03):203-210; Pottery Summary",
#       "slug": "24-amadbb-i-2008-08-03203-210-pottery-summary",
#       "rdfs:isDefinedBy": "http://opencontext.org/documents/e78efdb6-807d-451a-8efd-270356462235",
#       "oc-api:descriptiveness": 1479.3000000000002,
#       "oc-api:human-remains-related": false,
#       "type": "Feature",
#       "category": "oc-api:geo-record",
#       "geometry": {
#         "id": "#record-geom-45-of-342720",
#         "type": "Point",
#         "coordinates": [
#           11.401270211576183,
#           43.15293647301977
#         ]
#       },
#       "when": {
#         "id": "#record-event-45-of-342720",
#         "event_type": "oc-gen:general-time-space",
#         "type": "Interval",
#         "start": "-0699",
#         "stop": "-0534"
#       },
#       "properties": {
#         "id": "#rec-45-of-342720",
#         "feature-type": "item record",
#         "label": "AMA/DBB I (2008-08-03):203-210; Pottery Summary",
#         "uri": "http://opencontext.org/documents/e78efdb6-807d-451a-8efd-270356462235",
#         "href": "https://opencontext.org/documents/e78efdb6-807d-451a-8efd-270356462235",
#         "citation uri": "https://n2t.net/ark:/28722/k2m61t45s",
#         "project label": "Murlo",
#         "project href": "https://opencontext.org/projects/df043419-f23b-41da-7e4d-ee52af22f92f",
#         "context label": "Europe/Italy/Poggio Civitate/Tesoro South Flank/Tesoro South Flank 4/2008, ID:602",
#         "context href": "https://opencontext.org/subjects/03c2f519-5258-4880-c762-42673862ad9e",
#         "early bce/ce": -700.0,
#         "late bce/ce": -535.0,
#         "item category": "Documents",
#         "icon": "https://opencontext.org/static/oc/icons-v2/noun-document-3183378.svg",
#         "published": "2017-10-04T09:42:06Z",
#         "updated": "2025-04-05T05:00:28Z"
#       }
#     },
#     {
#       "id": "#record-46-of-342720",
#       "label": "2672",
#       "slug": "104-2672",
#       "rdfs:isDefinedBy": "http://opencontext.org/media/99496876-67e8-408f-8da6-212f515ef67f",
#       "oc-api:descriptiveness": 1447.13942,
#       "oc-api:human-remains-related": false,
#       "type": "Feature",
#       "category": "oc-api:geo-record",
#       "geometry": {
#         "id": "#record-geom-46-of-342720",
#         "type": "Point",
#         "coordinates": [
#           12.719486146888293,
#           41.88774442934475
#         ]
#       },
#       "when": {
#         "id": "#record-event-46-of-342720",
#         "event_type": "oc-gen:general-time-space",
#         "type": "Interval",
#         "start": "-0674",
#         "stop": "0001"
#       },
#       "properties": {
#         "id": "#rec-46-of-342720",
#         "feature-type": "item record",
#         "label": "2672",
#         "uri": "http://opencontext.org/media/99496876-67e8-408f-8da6-212f515ef67f",
#         "href": "https://opencontext.org/media/99496876-67e8-408f-8da6-212f515ef67f",
#         "citation uri": "https://n2t.net/ark:/28722/k2cv4rg9w",
#         "project label": "The Gabii Project",
#         "project href": "https://opencontext.org/projects/3585b372-8d2d-436c-9a4c-b5c10fce3ccd",
#         "context label": "Europe/Italy/Gabii/Area B/Unit 1242",
#         "context href": "https://opencontext.org/subjects/4d680e71-b622-42eb-9577-bd0eec2a8251",
#         "early bce/ce": -675.0,
#         "late bce/ce": 0.0,
#         "item category": "3D media",
#         "icon": "https://opencontext.org/static/oc/icons-v2/noun-3d-model-file-966229.svg",
#         "snippet": "  The Gabii Project  3D media  Photo Model  PM158_SU1242.pdf  Tile fall south of wall   Medium  2672.pdf   Excavations (Archaeology)   <mark>Roman</mark> Republican   <mark>Roman</mark> Imperial ",
#         "thumbnail": "https://opencontext.org/static/oc/images/icons/3d-noun-37529.png",
#         "published": "2017-06-04T23:26:17Z",
#         "updated": "2025-04-02T22:30:21Z"
#       }
#     },
#     {
#       "id": "#record-47-of-342720",
#       "label": "KD II (2015-08-04):443-476; Pottery Summary",
#       "slug": "24-kd-ii-2015-08-04443-476-pottery-summary",
#       "rdfs:isDefinedBy": "http://opencontext.org/documents/e2ebc0b6-5881-4610-8e92-5739bffc5c4d",
#       "oc-api:descriptiveness": 1436.1550000000002,
#       "oc-api:human-remains-related": false,
#       "type": "Feature",
#       "category": "oc-api:geo-record",
#       "geometry": {
#         "id": "#record-geom-47-of-342720",
#         "type": "Point",
#         "coordinates": [
#           11.400920037820631,
#           43.1528440271374
#         ]
#       },
#       "when": {
#         "id": "#record-event-47-of-342720",
#         "event_type": "oc-gen:general-time-space",
#         "type": "Interval",
#         "start": "-0699",
#         "stop": "-0534"
#       },
#       "properties": {
#         "id": "#rec-47-of-342720",
#         "feature-type": "item record",
#         "label": "KD II (2015-08-04):443-476; Pottery Summary",
#         "uri": "http://opencontext.org/documents/e2ebc0b6-5881-4610-8e92-5739bffc5c4d",
#         "href": "https://opencontext.org/documents/e2ebc0b6-5881-4610-8e92-5739bffc5c4d",
#         "citation uri": "https://n2t.net/ark:/28722/k29314713",
#         "project label": "Murlo",
#         "project href": "https://opencontext.org/projects/df043419-f23b-41da-7e4d-ee52af22f92f",
#         "context label": "Europe/Italy/Poggio Civitate/Tesoro/Tesoro 66/2015, ID:700",
#         "context href": "https://opencontext.org/subjects/9420190e-3d76-44cf-ae0f-279900c4a56c",
#         "early bce/ce": -700.0,
#         "late bce/ce": -535.0,
#         "item category": "Documents",
#         "icon": "https://opencontext.org/static/oc/icons-v2/noun-document-3183378.svg",
#         "published": "2017-10-04T09:59:20Z",
#         "updated": "2025-04-05T03:53:34Z"
#       }
#     },
#     {
#       "id": "#record-48-of-342720",
#       "label": "KM416ab-D14-001-Cf",
#       "slug": "177-km416ab-d14-001-cf",
#       "rdfs:isDefinedBy": "http://opencontext.org/media/6dcb067c-591f-44e2-b88c-e5b2e93e27ba",
#       "oc-api:descriptiveness": 1432.82004,
#       "oc-api:human-remains-related": false,
#       "type": "Feature",
#       "category": "oc-api:geo-record",
#       "geometry": {
#         "id": "#record-geom-48-of-342720",
#         "type": "Point",
#         "coordinates": [
#           22.992532,
#           37.88239
#         ]
#       },
#       "when": {
#         "id": "#record-event-48-of-342720",
#         "event_type": "oc-gen:general-time-space",
#         "type": "Interval",
#         "start": "0050",
#         "stop": "0125"
#       },
#       "properties": {
#         "id": "#rec-48-of-342720",
#         "feature-type": "item record",
#         "label": "KM416ab-D14-001-Cf",
#         "uri": "http://opencontext.org/media/6dcb067c-591f-44e2-b88c-e5b2e93e27ba",
#         "href": "https://opencontext.org/media/6dcb067c-591f-44e2-b88c-e5b2e93e27ba",
#         "citation uri": "https://n2t.net/ark:/28722/k2xs64s43",
#         "project label": "The Greek-American Excavations at Koutsongila, Kenchreai",
#         "project href": "https://opencontext.org/projects/ce8fcc0f-adff-4ece-a1c6-634326ed8a23",
#         "context label": "Europe/Greece/Kenchreai/TRB0905-024/Object 541",
#         "context href": "https://opencontext.org/subjects/9d36d72f-85c2-46e7-87e5-786089baa57e",
#         "early bce/ce": 50.0,
#         "late bce/ce": 125.0,
#         "item category": "Image media",
#         "icon": "https://opencontext.org/static/oc/icons-v2/noun-image-file-1453705.svg",
#         "snippet": "  Image media  Finds, inventoried  KM416a/b  541  TRB0905-024  Glass cup/small deep bowl   Early <mark>Roman</mark> ",
#         "thumbnail": "https://artiraq.org/static/opencontext/rife-kenchreai/thumbs/finds-inventoried/KM416ab-D14-001-Cf.jpg",
#         "published": "2007-01-01T00:00:00Z",
#         "updated": "2025-04-04T22:55:37Z"
#       }
#     },
#     {
#       "id": "#record-49-of-342720",
#       "label": "T114-2025 (2025-08-05):195-248; other",
#       "slug": "24-t114-2025-2025-08-05195-248-other",
#       "rdfs:isDefinedBy": "http://opencontext.org/documents/76b857bf-3f7f-462a-9518-bfe33985d5fb",
#       "oc-api:descriptiveness": 1430.9050000000002,
#       "oc-api:human-remains-related": false,
#       "type": "Feature",
#       "category": "oc-api:geo-record",
#       "geometry": {
#         "id": "#record-geom-49-of-342720",
#         "type": "Point",
#         "coordinates": [
#           11.402819672617,
#           43.152609876758
#         ]
#       },
#       "when": {
#         "id": "#record-event-49-of-342720",
#         "event_type": "oc-gen:general-time-space",
#         "type": "Interval",
#         "start": "-0699",
#         "stop": "-0534"
#       },
#       "properties": {
#         "id": "#rec-49-of-342720",
#         "feature-type": "item record",
#         "label": "T114-2025 (2025-08-05):195-248; other",
#         "uri": "http://opencontext.org/documents/76b857bf-3f7f-462a-9518-bfe33985d5fb",
#         "href": "https://opencontext.org/documents/76b857bf-3f7f-462a-9518-bfe33985d5fb",
#         "citation uri": null,
#         "project label": "Murlo",
#         "project href": "https://opencontext.org/projects/df043419-f23b-41da-7e4d-ee52af22f92f",
#         "context label": "Europe/Italy/Poggio Civitate/Tesoro/Tesoro 114/T114 2025",
#         "context href": "https://opencontext.org/subjects/e9e24924-b40d-4237-b32b-a3d170c4f109",
#         "early bce/ce": -700.0,
#         "late bce/ce": -535.0,
#         "item category": "Locus",
#         "icon": "https://opencontext.org/static/oc/icons-v2/noun-document-3183378.svg",
#         "published": "2012-07-06T00:00:00Z",
#         "updated": "2025-09-29T21:26:13Z"
#       }
#     },
#     {
#       "id": "#record-50-of-342720",
#       "label": "NM II (1989-07-27):262-273; Daily Log",
#       "slug": "24-nm-ii-1989-07-27262-273-daily-log",
#       "rdfs:isDefinedBy": "http://opencontext.org/documents/519867e8-8f71-4017-be45-fad172a38128",
#       "oc-api:descriptiveness": 1429.755,
#       "oc-api:human-remains-related": false,
#       "type": "Feature",
#       "category": "oc-api:geo-record",
#       "geometry": {
#         "id": "#record-geom-50-of-342720",
#         "type": "Point",
#         "coordinates": [
#           11.402015740135283,
#           43.152648338284486
#         ]
#       },
#       "when": {
#         "id": "#record-event-50-of-342720",
#         "event_type": "oc-gen:general-time-space",
#         "type": "Interval",
#         "start": "-0699",
#         "stop": "-0534"
#       },
#       "properties": {
#         "id": "#rec-50-of-342720",
#         "feature-type": "item record",
#         "label": "NM II (1989-07-27):262-273; Daily Log",
#         "uri": "http://opencontext.org/documents/519867e8-8f71-4017-be45-fad172a38128",
#         "href": "https://opencontext.org/documents/519867e8-8f71-4017-be45-fad172a38128",
#         "citation uri": "https://n2t.net/ark:/28722/k2fj2rq7t",
#         "project label": "Murlo",
#         "project href": "https://opencontext.org/projects/df043419-f23b-41da-7e4d-ee52af22f92f",
#         "context label": "Europe/Italy/Poggio Civitate/Tesoro/Tesoro 26/1989, ID:134/PC 19890089",
#         "context href": "https://opencontext.org/subjects/00404a9b-8c56-4ad6-3160-ce3b7ae2e74a",
#         "early bce/ce": -700.0,
#         "late bce/ce": -535.0,
#         "item category": "Documents",
#         "icon": "https://opencontext.org/static/oc/icons-v2/noun-document-3183378.svg",
#         "thumbnail": "https://artiraq.org/static/opencontext/poggio-civitate/thumbs/trenchbookimages/uncropped/NMeyerII_272,273.JPG",
#         "published": "2017-10-04T10:08:05Z",
#         "updated": "2025-04-05T04:13:03Z"
#       }
#     }
#   ],
#   "Qtime": 1426
# }

# %%
# dump json to file that can be found in "data" folder
import json
with open('../data/open-context-romandata.json', 'w') as outfile:
    json.dump(data, outfile)
