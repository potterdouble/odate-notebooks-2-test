# %%
# Make the Requests module available
import requests

# %%
# Create a variable called 'api_search_url' and give it a value
api_search_url = 'https://api.si.edu/openaccess/api/v1.0/search'

# %%
# create a variable to hold your API key, which you can obtain at
# https://api.data.gov/signup/

api_key = "o8wb1kfkhQGb7Guel4a34hmjoUjHUuEipcLHg3dk"

# %%
# This creates a dictionary called 'params' and sets values for the API's mandatory parameters
params = {
    'q': 'Ottawa' # Search for this keyword -- feel free to change!
}

# %%
params ['api_key'] = api_key # note that 'lt' means 'less thant'; adding this to the query

# params['format'] = 'json'

# %%
# This sends our request to the API and stores the result in a variable called 'response'
response = requests.get(api_search_url, params=params)

# This shows us the url that's sent to the API
print('Here\'s the formatted url that gets sent to the our Datasette API:\n{}\n'.format(response.url)) 

# This checks the status code of the response to make sure there were no errors
if response.status_code == requests.codes.ok:
    print('All ok')
elif response.status_code == 403:
    print('There was an authentication error. Did you paste your API above?')
else:
    print('There was a problem. Error code: {}'.format(response.status_code))
    print('Try running this cell again.')
# Out:
# Here's the formatted url that gets sent to the our Datasette API:
# https://api.si.edu/openaccess/api/v1.0/search?q=Ottawa&api_key=o8wb1kfkhQGb7Guel4a34hmjoUjHUuEipcLHg3dk
#
# All ok

# %%
# Get the API's JSON results and make them available as a Python variable called 'data'
data = response.json()

# %%
# Let's prettify the raw JSON data and then display it.

# We're using the Pygments library to add some colour to the output, so we need to import it
import json
from pygments import highlight, lexers, formatters

# This uses Python's JSON module to output the results as nicely indented text
formatted_data = json.dumps(data, indent=2)

# This colours the text
highlighted_data = highlight(formatted_data, lexers.JsonLexer(), formatters.TerminalFormatter())

# And now display the results
print(highlighted_data)
# Out:
# {
#   "status": 200,
#   "responseCode": 1,
#   "response": {
#     "rows": [
#       {
#         "id": "ld1-1646149545906-1646149584145-0",
#         "title": "Instruction book : how to care for and operate Ottawa log saws ... / Ottawa Manufacturing Company",
#         "unitCode": "SIL",
#         "type": "edanmdm",
#         "url": "edanmdm:siris_sil_545181",
#         "content": {
#           "freetext": {
#             "date": [
#               {
#                 "label": "Date",
#                 "content": "199u"
#               },
#               {
#                 "label": "Date",
#                 "content": "1920"
#               },
#               {
#                 "label": "Date",
#                 "content": "[199-?]"
#               }
#             ],
#             "name": [
#               {
#                 "label": "Author",
#                 "content": "Ottawa Manufacturing Company"
#               },
#               {
#                 "label": "Subject",
#                 "content": "Ottawa Manufacturing Company"
#               }
#             ],
#             "notes": [
#               {
#                 "label": "Notes",
#                 "content": "Trade literature."
#               },
#               {
#                 "label": "Notes",
#                 "content": "Cover title."
#               },
#               {
#                 "label": "Notes",
#                 "content": "Reprint. Originally published: Ottawa, Kan.: Ottawa Manufacturing Co., [1920?]"
#               }
#             ],
#             "title": [
#               {
#                 "label": "Title",
#                 "content": "How to care for and operate Ottawa log saws .."
#               }
#             ],
#             "topic": [
#               {
#                 "label": "Topic",
#                 "content": "Power tools"
#               },
#               {
#                 "label": "Topic",
#                 "content": "Saws"
#               }
#             ],
#             "dataSource": [
#               {
#                 "label": "Data Source",
#                 "content": "Smithsonian Libraries"
#               }
#             ],
#             "identifier": [
#               {
#                 "label": "Call number",
#                 "content": "050375"
#               }
#             ],
#             "objectType": [
#               {
#                 "label": "Type",
#                 "content": "Catalogs"
#               },
#               {
#                 "label": "Type",
#                 "content": "Trade catalogs"
#               }
#             ],
#             "physicalDescription": [
#               {
#                 "label": "Physical description",
#                 "content": "31 p. : ill. ; 18 cm"
#               }
#             ]
#           },
#           "indexedStructured": {
#             "date": [
#               "1920s",
#               "1990s"
#             ],
#             "name": [
#               "Ottawa Manufacturing Company"
#             ],
#             "topic": [
#               "Saws",
#               "Power tools"
#             ],
#             "language": [
#               "English language"
#             ],
#             "object_type": [
#               "Catalogs",
#               "Trade catalogs"
#             ]
#           },
#           "descriptiveNonRepeating": {
#             "title": {
#               "label": "Title",
#               "content": "Instruction book : how to care for and operate Ottawa log saws ... / Ottawa Manufacturing Company"
#             },
#             "record_ID": "siris_sil_545181",
#             "unit_code": "SIL",
#             "title_sort": "INSTRUCTION BOOK : HOW TO CARE FOR AND OPERATE OTTAWA LOG SAWS OTTAWA MANUFACTURING COMPANY",
#             "data_source": "Smithsonian Libraries",
#             "record_link": "https://siris-libraries.si.edu/ipac20/ipac.jsp?&profile=liball&source=~!silibraries&uri=full=3100001~!545181~!0#focus",
#             "metadata_usage": {
#               "text": "",
#               "access": "CC0"
#             }
#           }
#         },
#         "hash": "bbb00b8b975350dc1d287d33d4f0200c79675b30",
#         "docSignature": "791790148f716a567e7149936837a0da",
#         "timestamp": "1498154247",
#         "lastTimeUpdated": "1661961844",
#         "version": "0"
#       },
#       {
#         "id": "ld1-1646149545906-1646150579712-0",
#         "title": "Reply of the Ottawa University, Franklin County, Kansas, to the petition of the Ottawa Indians",
#         "unitCode": "SIL",
#         "type": "edanmdm",
#         "url": "edanmdm:siris_sil_503215",
#         "content": {
#           "freetext": {
#             "date": [
#               {
#                 "label": "Date",
#                 "content": "1871"
#               },
#               {
#                 "label": "Date",
#                 "content": "1871?]"
#               }
#             ],
#             "name": [
#               {
#                 "label": "Author",
#                 "content": "Ottawa University (Kan.)"
#               },
#               {
#                 "label": "Author",
#                 "content": "Beard, Henry attorney"
#               },
#               {
#                 "label": "Subject",
#                 "content": "Ottawa University (Kan.)"
#               }
#             ],
#             "notes": [
#               {
#                 "label": "Notes",
#                 "content": "Caption title."
#               },
#               {
#                 "label": "Notes",
#                 "content": "Presented to the Senate of the United States, March 17, 1871."
#               },
#               {
#                 "label": "Notes",
#                 "content": "Signed: Henry Beard, attorney for Ottawa University."
#               }
#             ],
#             "topic": [
#               {
#                 "label": "Topic",
#                 "content": "Claims"
#               }
#             ],
#             "dataSource": [
#               {
#                 "label": "Data Source",
#                 "content": "Smithsonian Libraries"
#               }
#             ],
#             "identifier": [
#               {
#                 "label": "Call number",
#                 "content": "E99.O9 O89 1871"
#               }
#             ],
#             "objectType": [
#               {
#                 "label": "Type",
#                 "content": "Books"
#               }
#             ],
#             "physicalDescription": [
#               {
#                 "label": "Physical description",
#                 "content": "8 p. ; 23 cm"
#               }
#             ]
#           },
#           "indexedStructured": {
#             "date": [
#               "1870s"
#             ],
#             "name": [
#               "Beard, Henry",
#               "Ottawa University (Kan.)"
#             ],
#             "topic": [
#               "Claims"
#             ],
#             "culture": [
#               "Ottawa Indians",
#               "Indians of North America",
#               "Native Americans"
#             ],
#             "language": [
#               "English language"
#             ],
#             "object_type": [
#               "Books"
#             ]
#           },
#           "descriptiveNonRepeating": {
#             "title": {
#               "label": "Title",
#               "content": "Reply of the Ottawa University, Franklin County, Kansas, to the petition of the Ottawa Indians"
#             },
#             "record_ID": "siris_sil_503215",
#             "unit_code": "SIL",
#             "title_sort": "REPLY OF THE OTTAWA UNIVERSITY FRANKLIN COUNTY KANSAS TO THE PETITION OF THE OTTAWA INDIANS",
#             "data_source": "Smithsonian Libraries",
#             "record_link": "https://siris-libraries.si.edu/ipac20/ipac.jsp?&profile=liball&source=~!silibraries&uri=full=3100001~!503215~!0#focus",
#             "metadata_usage": {
#               "text": "",
#               "access": "CC0"
#             }
#           }
#         },
#         "hash": "b838e18c52a92b313706c77b6946e1750c29a984",
#         "docSignature": "2632cf1fe6452a3335e7d0d72e82bf2e",
#         "timestamp": "1498154247",
#         "lastTimeUpdated": "1661961967",
#         "version": "0"
#       },
#       {
#         "id": "ld1-1642011380463-1642011381206-0",
#         "title": "[Trade catalogs from Ottawa Steel Products]",
#         "unitCode": "SILNMAHTL",
#         "type": "edanmdm",
#         "url": "edanmdm:SILNMAHTL_30768",
#         "content": {
#           "freetext": {
#             "date": [
#               {
#                 "label": "Date",
#                 "content": "1900s"
#               }
#             ],
#             "name": [
#               {
#                 "label": "Company Name",
#                 "content": "Ottawa Steel Products"
#               },
#               {
#                 "label": "Related companies",
#                 "content": "Daybrook-Ottawa Corp."
#               }
#             ],
#             "place": [
#               {
#                 "label": "Place",
#                 "content": "Ottawa, Kansas, United States"
#               }
#             ],
#             "topic": [
#               {
#                 "label": "Topic (Romaine term)",
#                 "content": "Construction and earth-moving machinery"
#               },
#               {
#                 "label": "Topic",
#                 "content": "Construction equipment"
#               },
#               {
#                 "label": "Topic",
#                 "content": "Earthmoving machinery"
#               }
#             ],
#             "setName": [
#               {
#                 "label": "Location",
#                 "content": "Trade Literature at the American History Museum Library"
#               },
#               {
#                 "label": "Collection",
#                 "content": "Smithsonian Libraries Trade Literature Collections"
#               }
#             ],
#             "language": [
#               {
#                 "label": "Language",
#                 "content": "English"
#               }
#             ],
#             "dataSource": [
#               {
#                 "label": "Data source",
#                 "content": "Smithsonian Libraries"
#               }
#             ],
#             "identifier": [
#               {
#                 "label": "Record ID",
#                 "content": "SILNMAHTL_30768"
#               }
#             ],
#             "objectType": [
#               {
#                 "label": "Type of material",
#                 "content": "Trade catalogs"
#               },
#               {
#                 "label": "Type of material",
#                 "content": "Trade literature"
#               }
#             ],
#             "physicalDescription": [
#               {
#                 "label": "Notes content",
#                 "content": "\"Ottawa\" hydra hammer line of construction and earth moving machinery."
#               },
#               {
#                 "label": "Includes",
#                 "content": "Trade catalog"
#               },
#               {
#                 "label": "Includes",
#                 "content": "Color images"
#               },
#               {
#                 "label": "Physical description",
#                 "content": "1 piece; 1 box"
#               }
#             ]
#           },
#           "indexedStructured": {
#             "date": [
#               "1920s",
#               "1910s",
#               "1940s",
#               "1930s",
#               "1900s",
#               "1990s",
#               "1960s",
#               "1950s",
#               "1980s",
#               "1970s"
#             ],
#             "name": [
#               {
#                 "type": "corporate_name",
#                 "content": "Ottawa Steel Products"
#               }
#             ],
#             "place": [
#               "United States",
#               "Ottawa",
#               "Kansas"
#             ],
#             "topic": [
#               "Construction equipment"
#             ],
#             "language": [
#               "English"
#             ],
#             "geoLocation": [
#               {
#                 "L2": {
#                   "type": "Country",
#                   "content": "United States"
#                 },
#                 "L3": {
#                   "type": "State",
#                   "content": "Kansas"
#                 },
#                 "L5": {
#                   "type": "City",
#                   "content": "Ottawa"
#                 }
#               }
#             ],
#             "object_type": [
#               "Trade catalogs"
#             ]
#           },
#           "descriptiveNonRepeating": {
#             "title": {
#               "label": "Title",
#               "content": "[Trade catalogs from Ottawa Steel Products]"
#             },
#             "record_ID": "SILNMAHTL_30768",
#             "unit_code": "SILNMAHTL",
#             "title_sort": "Trade catalogs from Ottawa Steel Products",
#             "data_source": "Smithsonian Libraries",
#             "metadata_usage": {
#               "text": "",
#               "access": "CC0"
#             }
#           }
#         },
#         "hash": "6f080831f6b7af756ae10a2f009f82605d41f579",
#         "docSignature": "1a3fa104bdaa0d26abf2e23759f8b5ea",
#         "timestamp": "1663785437",
#         "lastTimeUpdated": "1666742642",
#         "version": "1666739154"
#       },
#       {
#         "id": "ld1-1646149545906-1646149578295-1",
#         "title": "The Ottawa naturalist",
#         "unitCode": "SIL",
#         "type": "edanmdm",
#         "url": "edanmdm:siris_sil_316070",
#         "content": {
#           "freetext": {
#             "date": [
#               {
#                 "label": "Date",
#                 "content": "1887"
#               }
#             ],
#             "name": [
#               {
#                 "label": "Author",
#                 "content": "Ottawa Field-Naturalists' Club"
#               }
#             ],
#             "notes": [
#               {
#                 "label": "Notes",
#                 "content": "GeoRef 0197-7482"
#               }
#             ],
#             "place": [
#               {
#                 "label": "Place",
#                 "content": "Canada"
#               },
#               {
#                 "label": "Place",
#                 "content": "Ottawa"
#               }
#             ],
#             "topic": [
#               {
#                 "label": "Topic",
#                 "content": "Natural history"
#               }
#             ],
#             "dataSource": [
#               {
#                 "label": "Data Source",
#                 "content": "Smithsonian Libraries"
#               }
#             ],
#             "identifier": [
#               {
#                 "label": "Call number",
#                 "content": "QH1.C213"
#               },
#               {
#                 "label": "Call number",
#                 "content": "QH1.C213"
#               }
#             ],
#             "objectType": [
#               {
#                 "label": "Type",
#                 "content": "Electronic resources"
#               }
#             ],
#             "physicalDescription": [
#               {
#                 "label": "Physical description",
#                 "content": "v. ill. 22-26 cm"
#               }
#             ]
#           },
#           "indexedStructured": {
#             "date": [
#               "1880s"
#             ],
#             "name": [
#               "Ottawa Field-Naturalists' Club"
#             ],
#             "place": [
#               "Canada",
#               "Ottawa"
#             ],
#             "topic": [
#               "Natural History"
#             ],
#             "language": [
#               "English language"
#             ],
#             "object_type": [
#               "Electronic information resources"
#             ]
#           },
#           "descriptiveNonRepeating": {
#             "title": {
#               "label": "Title",
#               "content": "The Ottawa naturalist"
#             },
#             "record_ID": "siris_sil_316070",
#             "unit_code": "SIL",
#             "title_sort": "OTTAWA NATURALIST",
#             "data_source": "Smithsonian Libraries",
#             "record_link": "https://siris-libraries.si.edu/ipac20/ipac.jsp?&profile=liball&source=~!silibraries&uri=full=3100001~!316070~!0#focus",
#             "metadata_usage": {
#               "text": "",
#               "access": "CC0"
#             }
#           }
#         },
#         "hash": "4881a3cc0e33776f7d19f9bc31834c54fd5517b4",
#         "docSignature": "fa355dbe55da0c301aa590665414107f",
#         "timestamp": "1498154099",
#         "lastTimeUpdated": "1661963369",
#         "version": "0"
#       },
#       {
#         "id": "ld1-1646149545906-1646150550420-0",
#         "title": "Transactions - Ottawa Field-Naturalists' Club",
#         "unitCode": "SIL",
#         "type": "edanmdm",
#         "url": "edanmdm:siris_sil_316071",
#         "content": {
#           "freetext": {
#             "date": [
#               {
#                 "label": "Date",
#                 "content": "1880"
#               }
#             ],
#             "name": [
#               {
#                 "label": "Author",
#                 "content": "Ottawa Field-Naturalists' Club"
#               }
#             ],
#             "topic": [
#               {
#                 "label": "Topic",
#                 "content": "Natural history--Canada--Ottawa"
#               }
#             ],
#             "dataSource": [
#               {
#                 "label": "Data Source",
#                 "content": "Smithsonian Libraries"
#               }
#             ],
#             "identifier": [
#               {
#                 "label": "Call number",
#                 "content": "QH1 .C213"
#               },
#               {
#                 "label": "Call number",
#                 "content": "QH1.C213"
#               }
#             ],
#             "objectType": [
#               {
#                 "label": "Type",
#                 "content": "Periodicals"
#               }
#             ],
#             "physicalDescription": [
#               {
#                 "label": "Physical description",
#                 "content": "7 no. ill. 22 cm"
#               }
#             ]
#           },
#           "indexedStructured": {
#             "date": [
#               "1880s"
#             ],
#             "name": [
#               "Ottawa Field-Naturalists' Club"
#             ],
#             "place": [
#               "Canada"
#             ],
#             "topic": [
#               "Natural History"
#             ],
#             "culture": [
#               "Ottawa Indians",
#               "Indians of North America",
#               "Native Americans"
#             ],
#             "language": [
#               "English language"
#             ],
#             "geoLocation": [
#               {
#                 "L1": {
#                   "type": "Continent",
#                   "content": "North America"
#                 },
#                 "L2": {
#                   "type": "Country",
#                   "content": "Canada"
#                 }
#               }
#             ],
#             "object_type": [
#               "Periodicals"
#             ]
#           },
#           "descriptiveNonRepeating": {
#             "title": {
#               "label": "Title",
#               "content": "Transactions - Ottawa Field-Naturalists' Club"
#             },
#             "record_ID": "siris_sil_316071",
#             "unit_code": "SIL",
#             "title_sort": "TRANSACTIONS OTTAWA FIELDNATURALISTS CLUB",
#             "data_source": "Smithsonian Libraries",
#             "record_link": "https://siris-libraries.si.edu/ipac20/ipac.jsp?&profile=liball&source=~!silibraries&uri=full=3100001~!316071~!0#focus",
#             "metadata_usage": {
#               "text": "",
#               "access": "CC0"
#             }
#           }
#         },
#         "hash": "e7ed905cacf2022f71a4916ccfa02d5efeaf1627",
#         "docSignature": "260e0414babbbca70f3e180169987449",
#         "timestamp": "1498154099",
#         "lastTimeUpdated": "1661963821",
#         "version": "0"
#       },
#       {
#         "id": "ld1-1642011390596-1642011393151-0",
#         "title": "[Trade catalogs from Ottawa Silica Co.]",
#         "unitCode": "SILNMAHTL",
#         "type": "edanmdm",
#         "url": "edanmdm:SILNMAHTL_30695",
#         "content": {
#           "freetext": {
#             "date": [
#               {
#                 "label": "Date",
#                 "content": "1900s"
#               }
#             ],
#             "name": [
#               {
#                 "label": "Company Name",
#                 "content": "Ottawa Silica Co."
#               },
#               {
#                 "label": "Related companies",
#                 "content": "United States Silica Co. (purchased by Ottawa in 1928)"
#               }
#             ],
#             "place": [
#               {
#                 "label": "Place",
#                 "content": "Ottawa, Illinois, United States"
#               }
#             ],
#             "topic": [
#               {
#                 "label": "Topic (Romaine term)",
#                 "content": "Industrial equipment or mechanical machinery (including supplies and components)"
#               },
#               {
#                 "label": "Topic",
#                 "content": "Industrial equipment"
#               },
#               {
#                 "label": "Topic",
#                 "content": "Machinery"
#               }
#             ],
#             "setName": [
#               {
#                 "label": "Location",
#                 "content": "Trade Literature at the American History Museum Library"
#               },
#               {
#                 "label": "Collection",
#                 "content": "Smithsonian Libraries Trade Literature Collections"
#               }
#             ],
#             "language": [
#               {
#                 "label": "Language",
#                 "content": "English"
#               }
#             ],
#             "dataSource": [
#               {
#                 "label": "Data source",
#                 "content": "Smithsonian Libraries"
#               }
#             ],
#             "identifier": [
#               {
#                 "label": "Record ID",
#                 "content": "SILNMAHTL_30695"
#               }
#             ],
#             "objectType": [
#               {
#                 "label": "Type of material",
#                 "content": "Trade catalogs"
#               },
#               {
#                 "label": "Type of material",
#                 "content": "Trade literature"
#               }
#             ],
#             "physicalDescription": [
#               {
#                 "label": "Notes content",
#                 "content": "Sand blast abrasives."
#               },
#               {
#                 "label": "Includes",
#                 "content": "Trade catalog"
#               },
#               {
#                 "label": "Includes",
#                 "content": "Black and white images"
#               },
#               {
#                 "label": "Physical description",
#                 "content": "1 piece; 1 box"
#               }
#             ]
#           },
#           "indexedStructured": {
#             "date": [
#               "1920s",
#               "1910s",
#               "1940s",
#               "1930s",
#               "1900s",
#               "1990s",
#               "1960s",
#               "1950s",
#               "1980s",
#               "1970s"
#             ],
#             "name": [
#               {
#                 "type": "corporate_name",
#                 "content": "Ottawa Silica Co."
#               }
#             ],
#             "place": [
#               "United States",
#               "Illinois",
#               "Ottawa"
#             ],
#             "topic": [
#               "Industrial equipment",
#               "Machinery"
#             ],
#             "language": [
#               "English"
#             ],
#             "geoLocation": [
#               {
#                 "L2": {
#                   "type": "Country",
#                   "content": "United States"
#                 },
#                 "L3": {
#                   "type": "State",
#                   "content": "Illinois"
#                 },
#                 "L5": {
#                   "type": "City",
#                   "content": "Ottawa"
#                 }
#               }
#             ],
#             "object_type": [
#               "Trade catalogs"
#             ]
#           },
#           "descriptiveNonRepeating": {
#             "title": {
#               "label": "Title",
#               "content": "[Trade catalogs from Ottawa Silica Co.]"
#             },
#             "record_ID": "SILNMAHTL_30695",
#             "unit_code": "SILNMAHTL",
#             "title_sort": "Trade catalogs from Ottawa Silica Co.",
#             "data_source": "Smithsonian Libraries",
#             "metadata_usage": {
#               "text": "",
#               "access": "CC0"
#             }
#           }
#         },
#         "hash": "9f09ad694115c60870528d1bcb88187ef43cb75a",
#         "docSignature": "2211b22745c6194208f3c86563dbd9eb",
#         "timestamp": "1663785437",
#         "lastTimeUpdated": "1666742642",
#         "version": "1666739154"
#       },
#       {
#         "id": "ld1-1646149545906-1646150720944-1",
#         "title": "Argument of A. N. Blacklidge, in behalf of the Ottawa Indians of Blanchard's Fork and Roche de Boeuf, in the matter of the Ottawa University, or Indian school, at Ottawa, Kansas",
#         "unitCode": "SIL",
#         "type": "edanmdm",
#         "url": "edanmdm:siris_sil_499755",
#         "content": {
#           "freetext": {
#             "date": [
#               {
#                 "label": "Date",
#                 "content": "1870"
#               }
#             ],
#             "name": [
#               {
#                 "label": "Author",
#                 "content": "Blacklidge, A. N"
#               }
#             ],
#             "notes": [
#               {
#                 "label": "Notes",
#                 "content": "\"Submitted August 30, 1870.\""
#               }
#             ],
#             "place": [
#               {
#                 "label": "Place",
#                 "content": "Kansas"
#               }
#             ],
#             "topic": [
#               {
#                 "label": "Topic",
#                 "content": "Government relations"
#               },
#               {
#                 "label": "Topic",
#                 "content": "Education"
#               }
#             ],
#             "dataSource": [
#               {
#                 "label": "Data Source",
#                 "content": "Smithsonian Libraries"
#               }
#             ],
#             "identifier": [
#               {
#                 "label": "Call number",
#                 "content": "E93 .B62 1870"
#               }
#             ],
#             "objectType": [
#               {
#                 "label": "Type",
#                 "content": "Books"
#               }
#             ],
#             "physicalDescription": [
#               {
#                 "label": "Physical description",
#                 "content": "40 p. 24 cm"
#               }
#             ]
#           },
#           "indexedStructured": {
#             "date": [
#               "1870s"
#             ],
#             "name": [
#               "Blacklidge, A. N"
#             ],
#             "place": [
#               "Kansas"
#             ],
#             "topic": [
#               "Education",
#               "Government relations"
#             ],
#             "culture": [
#               "Ottawa Indians",
#               "Indians of North America",
#               "Native Americans"
#             ],
#             "language": [
#               "English language"
#             ],
#             "object_type": [
#               "Books"
#             ]
#           },
#           "descriptiveNonRepeating": {
#             "title": {
#               "label": "Title",
#               "content": "Argument of A. N. Blacklidge, in behalf of the Ottawa Indians of Blanchard's Fork and Roche de Boeuf, in the matter of the Ottawa University, or Indian school, at Ottawa, Kansas"
#             },
#             "record_ID": "siris_sil_499755",
#             "unit_code": "SIL",
#             "title_sort": "ARGUMENT OF A N BLACKLIDGE IN BEHALF OF THE OTTAWA INDIANS OF BLANCHARDS FORK AND ROCHE DE BOEUF IN THE MATTER OF THE OTTAWA UNIVERSITY OR INDIAN SCHOOL AT OTTAWA KANSAS",
#             "data_source": "Smithsonian Libraries",
#             "record_link": "https://siris-libraries.si.edu/ipac20/ipac.jsp?&profile=liball&source=~!silibraries&uri=full=3100001~!499755~!0#focus",
#             "metadata_usage": {
#               "text": "",
#               "access": "CC0"
#             }
#           }
#         },
#         "hash": "05f629e69932904f91862927ae7ff5e7a2d9e779",
#         "docSignature": "ee9b748a22e357d95fbc5c977f329c82",
#         "timestamp": "1498154178",
#         "lastTimeUpdated": "1661969569",
#         "version": "0"
#       },
#       {
#         "id": "ld1-1646149545906-1646150813562-2",
#         "title": "Settlement between the Trustees of Ottawa University, the Ottawa Indians of Blanchard's Fork and Roche de Boeuf, and the Baptist Home Mission Society : approved by the Secretary of the Interior, October 29, 1873",
#         "unitCode": "SIL",
#         "type": "edanmdm",
#         "url": "edanmdm:siris_sil_503219",
#         "content": {
#           "freetext": {
#             "date": [
#               {
#                 "label": "Date",
#                 "content": "1873"
#               },
#               {
#                 "label": "Date",
#                 "content": "1873?]"
#               }
#             ],
#             "name": [
#               {
#                 "label": "Author",
#                 "content": "Ottawa University (Kan.) Board of Trustees"
#               },
#               {
#                 "label": "Author",
#                 "content": "Ottawa Indians of the United Bands of Blanchard's Fork and of Roche de Boeuf"
#               },
#               {
#                 "label": "Author",
#                 "content": "American Baptist Home Mission Society"
#               },
#               {
#                 "label": "Author",
#                 "content": "United States Department of the Interior"
#               },
#               {
#                 "label": "Author",
#                 "content": "Ottawa Indians of the United Bands of Blanchard's Fork and of Roche de Boeuf Treaties, etc United States 1862 June 24"
#               },
#               {
#                 "label": "Subject",
#                 "content": "Ottawa University (Kan.)"
#               }
#             ],
#             "notes": [
#               {
#                 "label": "Notes",
#                 "content": "Caption title."
#               },
#               {
#                 "label": "Notes",
#                 "content": "Includes: An act repealing an act entitled, \"An act for the relief of certain Indians in the Central Superintendency,\" approved June tenth, eighteen hundred and seventy-two (p. 6-8)."
#               }
#             ],
#             "place": [
#               {
#                 "label": "Place",
#                 "content": "Kansas"
#               }
#             ],
#             "topic": [
#               {
#                 "label": "Topic",
#                 "content": "Land tenure"
#               },
#               {
#                 "label": "Topic",
#                 "content": "Finance"
#               },
#               {
#                 "label": "Topic",
#                 "content": "Education--Law and legislation"
#               },
#               {
#                 "label": "Topic",
#                 "content": "School lands"
#               },
#               {
#                 "label": "Topic",
#                 "content": "Land grants"
#               }
#             ],
#             "dataSource": [
#               {
#                 "label": "Data Source",
#                 "content": "Smithsonian Libraries"
#               }
#             ],
#             "identifier": [
#               {
#                 "label": "Call number",
#                 "content": "E99.O9 S49 1873"
#               }
#             ],
#             "objectType": [
#               {
#                 "label": "Type",
#                 "content": "Books"
#               }
#             ],
#             "physicalDescription": [
#               {
#                 "label": "Physical description",
#                 "content": "8 p. ; 24 cm"
#               }
#             ]
#           },
#           "indexedStructured": {
#             "date": [
#               "1870s"
#             ],
#             "name": [
#               "United States",
#               "American Baptist Home Mission Society",
#               "Ottawa Indians of the United Bands of Blanchard's Fork and of Roche de Boeuf",
#               "Ottawa University (Kan.)"
#             ],
#             "place": [
#               "Kansas"
#             ],
#             "topic": [
#               "Land tenure",
#               "Education",
#               "Law and legislation",
#               "Finance",
#               "School lands",
#               "Land grants"
#             ],
#             "culture": [
#               "Ottawa Indians",
#               "Indians of North America",
#               "Native Americans"
#             ],
#             "language": [
#               "English language"
#             ],
#             "object_type": [
#               "Books"
#             ]
#           },
#           "descriptiveNonRepeating": {
#             "title": {
#               "label": "Title",
#               "content": "Settlement between the Trustees of Ottawa University, the Ottawa Indians of Blanchard's Fork and Roche de Boeuf, and the Baptist Home Mission Society : approved by the Secretary of the Interior, October 29, 1873"
#             },
#             "record_ID": "siris_sil_503219",
#             "unit_code": "SIL",
#             "title_sort": "SETTLEMENT BETWEEN THE TRUSTEES OF OTTAWA UNIVERSITY THE OTTAWA INDIANS OF BLANCHARDS FORK AND ROCHE DE BOEUF AND THE BAPTIST HOME MISSION SOCIETY : APPROVED BY THE SECRETARY OF THE INTERIOR OCTOBER 29 1873",
#             "data_source": "Smithsonian Libraries",
#             "record_link": "https://siris-libraries.si.edu/ipac20/ipac.jsp?&profile=liball&source=~!silibraries&uri=full=3100001~!503219~!0#focus",
#             "metadata_usage": {
#               "text": "",
#               "access": "CC0"
#             }
#           }
#         },
#         "hash": "7c4d6e53378c203cef9fea9b04b9213e7eb1fa48",
#         "docSignature": "465faff53d73a03daf92f9893ce36f08",
#         "timestamp": "1498154247",
#         "lastTimeUpdated": "1661961936",
#         "version": "0"
#       },
#       {
#         "id": "ld1-1642011380463-1642011383484-0",
#         "title": "[Trade catalogs from Ottawa Mfg. Co.]",
#         "unitCode": "SILNMAHTL",
#         "type": "edanmdm",
#         "url": "edanmdm:SILNMAHTL_30693",
#         "content": {
#           "freetext": {
#             "date": [
#               {
#                 "label": "Date",
#                 "content": "1900s"
#               }
#             ],
#             "name": [
#               {
#                 "label": "Company Name",
#                 "content": "Ottawa Mfg. Co."
#               }
#             ],
#             "place": [
#               {
#                 "label": "Place",
#                 "content": "Ottawa, Kansas, United States"
#               }
#             ],
#             "topic": [
#               {
#                 "label": "Topic (Romaine term)",
#                 "content": "Engines and motors: steam; oil; gas; etc."
#               },
#               {
#                 "label": "Topic (Romaine term)",
#                 "content": "Lumber; logging; timber and forestry"
#               },
#               {
#                 "label": "Topic",
#                 "content": "Engines"
#               },
#               {
#                 "label": "Topic",
#                 "content": "Forests and forestry"
#               },
#               {
#                 "label": "Topic",
#                 "content": "Lumber"
#               },
#               {
#                 "label": "Topic",
#                 "content": "Motors"
#               },
#               {
#                 "label": "Topic",
#                 "content": "Timber"
#               }
#             ],
#             "setName": [
#               {
#                 "label": "Location",
#                 "content": "Trade Literature at the American History Museum Library"
#               },
#               {
#                 "label": "Collection",
#                 "content": "Smithsonian Libraries Trade Literature Collections"
#               }
#             ],
#             "language": [
#               {
#                 "label": "Language",
#                 "content": "English"
#               }
#             ],
#             "dataSource": [
#               {
#                 "label": "Data source",
#                 "content": "Smithsonian Libraries"
#               }
#             ],
#             "identifier": [
#               {
#                 "label": "Record ID",
#                 "content": "SILNMAHTL_30693"
#               }
#             ],
#             "objectType": [
#               {
#                 "label": "Type of material",
#                 "content": "Trade catalogs"
#               },
#               {
#                 "label": "Type of material",
#                 "content": "Trade literature"
#               }
#             ],
#             "physicalDescription": [
#               {
#                 "label": "Notes content",
#                 "content": "\"Ottawa\" engines ; log saws ; buzz saw rigs."
#               },
#               {
#                 "label": "Includes",
#                 "content": "Trade catalog"
#               },
#               {
#                 "label": "Includes",
#                 "content": "Black and white images"
#               },
#               {
#                 "label": "Includes",
#                 "content": "Color images"
#               },
#               {
#                 "label": "Physical description",
#                 "content": "6 pieces; 2 boxes"
#               }
#             ]
#           },
#           "indexedStructured": {
#             "date": [
#               "1920s",
#               "1910s",
#               "1940s",
#               "1930s",
#               "1900s",
#               "1990s",
#               "1960s",
#               "1950s",
#               "1980s",
#               "1970s"
#             ],
#             "name": [
#               {
#                 "type": "corporate_name",
#                 "content": "Ottawa Mfg. Co."
#               }
#             ],
#             "place": [
#               "United States",
#               "Ottawa",
#               "Kansas"
#             ],
#             "topic": [
#               "Timber",
#               "Motors",
#               "Forests and forestry",
#               "Engines",
#               "Lumber"
#             ],
#             "language": [
#               "English"
#             ],
#             "geoLocation": [
#               {
#                 "L2": {
#                   "type": "Country",
#                   "content": "United States"
#                 },
#                 "L3": {
#                   "type": "State",
#                   "content": "Kansas"
#                 },
#                 "L5": {
#                   "type": "City",
#                   "content": "Ottawa"
#                 }
#               }
#             ],
#             "object_type": [
#               "Trade catalogs"
#             ]
#           },
#           "descriptiveNonRepeating": {
#             "title": {
#               "label": "Title",
#               "content": "[Trade catalogs from Ottawa Mfg. Co.]"
#             },
#             "record_ID": "SILNMAHTL_30693",
#             "unit_code": "SILNMAHTL",
#             "title_sort": "Trade catalogs from Ottawa Mfg. Co.",
#             "data_source": "Smithsonian Libraries",
#             "metadata_usage": {
#               "text": "",
#               "access": "CC0"
#             }
#           }
#         },
#         "hash": "8c4f3451223075f93d6334e617f1c28715e7d07a",
#         "docSignature": "d91ead53d06a0ffda639776a021226e9",
#         "timestamp": "1663785437",
#         "lastTimeUpdated": "1666742642",
#         "version": "1666739154"
#       },
#       {
#         "id": "ld1-1646149545906-1646150193653-1",
#         "title": "Anthropologica",
#         "unitCode": "SIL",
#         "type": "edanmdm",
#         "url": "edanmdm:siris_sil_313723",
#         "content": {
#           "freetext": {
#             "date": [
#               {
#                 "label": "Date",
#                 "content": "1955"
#               }
#             ],
#             "name": [
#               {
#                 "label": "Author",
#                 "content": "Canadian Anthropology Society"
#               },
#               {
#                 "label": "Author",
#                 "content": "University of Ottawa Research Center for Amerindian Anthropology"
#               },
#               {
#                 "label": "Author",
#                 "content": "University of Ottawa Canadian Research Centre for Anthropology"
#               },
#               {
#                 "label": "Author",
#                 "content": "Saint Paul University (Ottawa, Ont.) Canadian Research Centre for Anthropology"
#               }
#             ],
#             "notes": [
#               {
#                 "label": "Notes",
#                 "content": "Available on microfiche from: Toronto : Micromedia."
#               },
#               {
#                 "label": "Notes",
#                 "content": "Available also by subscription via the World Wide Web; access available via SIL PURL."
#               },
#               {
#                 "label": "Notes",
#                 "content": "Issued 1955-1959 by the University of Ottawa, Research Center for Amerindian Anthropology; 1960-1966 by the University of Ottawa, Canadian Research Centre for Anthropology; 1967-1982 by Saint Paul University (Ottawa, Ont.) Canadian Research Centre for Anthropology; 1983-1988 by Laurentian University; 1998- Canadian Anthropology Society (CASCA)."
#               },
#               {
#                 "label": "Notes",
#                 "content": "Index: 1955-1965 in v. 7."
#               },
#               {
#                 "label": "Notes",
#                 "content": "Absorbed with v. 40 (1998): Culture (Canadian Anthropology Society)"
#               },
#               {
#                 "label": "Notes",
#                 "content": "Elecresource"
#               }
#             ],
#             "place": [
#               {
#                 "label": "Place",
#                 "content": "Canada"
#               }
#             ],
#             "dataSource": [
#               {
#                 "label": "Data Source",
#                 "content": "Smithsonian Libraries"
#               }
#             ],
#             "identifier": [
#               {
#                 "label": "Call number",
#                 "content": "E78.C2 A53X"
#               }
#             ],
#             "objectType": [
#               {
#                 "label": "Type",
#                 "content": "Periodicals"
#               }
#             ],
#             "physicalDescription": [
#               {
#                 "label": "Physical description",
#                 "content": "v. ill. 23-27 cm"
#               }
#             ]
#           },
#           "indexedStructured": {
#             "date": [
#               "1950s"
#             ],
#             "name": [
#               "Canadian Anthropology Society",
#               "Saint Paul University (Ottawa, Ont.)",
#               "University of Ottawa"
#             ],
#             "place": [
#               "Canada"
#             ],
#             "culture": [
#               "Indians of North America",
#               "Native Americans"
#             ],
#             "language": [
#               "English language",
#               "French language"
#             ],
#             "object_type": [
#               "Periodicals"
#             ]
#           },
#           "descriptiveNonRepeating": {
#             "title": {
#               "label": "Title",
#               "content": "Anthropologica"
#             },
#             "record_ID": "siris_sil_313723",
#             "unit_code": "SIL",
#             "title_sort": "ANTHROPOLOGICA",
#             "data_source": "Smithsonian Libraries",
#             "record_link": "https://siris-libraries.si.edu/ipac20/ipac.jsp?&profile=liball&source=~!silibraries&uri=full=3100001~!313723~!0#focus",
#             "metadata_usage": {
#               "access": "CC0"
#             }
#           }
#         },
#         "hash": "e636c178219dd7ab20ead4afd1bc419b79708301",
#         "docSignature": "dfb386ff1e09571409a9759186f022e0",
#         "timestamp": "1616055069",
#         "lastTimeUpdated": "1661963820",
#         "version": "0"
#       }
#     ],
#     "facets": {},
#     "rowCount": 5943,
#     "message": "content found"
#   }
# }

# %%
# dump json to file that can be found in "data" folder
import json
with open('../data/smithsonian-data.json', 'w') as outfile:
    json.dump(data, outfile)

# %% [markdown]
# API documentation is at https://edan.si.edu/openaccess/apidocs/#api-search. Notice the latitude, longitude fields? Maybe we can map thiose using the mapping with leaflet notebook.
