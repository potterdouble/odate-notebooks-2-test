# %% [markdown]
# # Linked Open Data Doesn't Have To Use SPARQL
#
# The [Pompeii Artistic Landscapes Project](https://palp.art/start) tries to describe all of the art that once hung on or was once part of the walls of Pompeii. It uses the idea of the 'triple' to describe the concepts, their interrelationships, and their locations:
#
# > The Pompeii Artistic Landscape Project (PALP) is an online resource that supports site-wide discovery, mapping, analysis, and sharing of information about Pompeian artworks in their architectural and urban contexts. The goal of PALP is to dramatically increase the number of researchers and members of the public who can access, analyze, interpret, and share the artworks of the most richly documented urban environment of the Roman world: Pompeii.
#
# The data is available through a variety of means (check out [p-lod](https://p-lod.org/)) but one way is through a python-powered application programming interface. You can think of this as a kind of alternative to the SPARQL approach we tried in the [sparql-and-lod.ipynb](sparql-and-lod.ipynb) notebook.
#
# So let's give it a quick whirl, shall we?

# %%
# !pip3 install git+https://github.com/p-lod/plodlib
# Out:
# Collecting git+https://github.com/p-lod/plodlib
#   Cloning https://github.com/p-lod/plodlib to C:\Users\Kegan\AppData\Local\Temp\pip-req-build-o_ylyup5
#   Resolved https://github.com/p-lod/plodlib to commit c0e8306511ed20abedcacc7c1fcccd6259b422de
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: pandas in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from plodlib==0.1.2) (3.0.2)
# Collecting rdflib>=7.0.0 (from plodlib==0.1.2)
#   Downloading rdflib-7.6.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: requests in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from plodlib==0.1.2) (2.33.1)
# Collecting pyparsing<4,>=2.1.0 (from rdflib>=7.0.0->plodlib==0.1.2)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: numpy>=2.3.3 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from pandas->plodlib==0.1.2) (2.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from pandas->plodlib==0.1.2) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from pandas->plodlib==0.1.2) (2026.1)
# Requirement already satisfied: six>=1.5 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from python-dateutil>=2.8.2->pandas->plodlib==0.1.2) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from requests->plodlib==0.1.2) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from requests->plodlib==0.1.2) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from requests->plodlib==0.1.2) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\Kegan\miniconda3\envs\odate-notebooks\Lib\site-packages (from requests->plodlib==0.1.2) (2026.1.4)
# Downloading rdflib-7.6.0-py3-none-any.whl (615 kB)
#    ---------------------------------------- 0.0/615.4 kB ? eta -:--:--
#    ---------------------------------------- 615.4/615.4 kB 19.3 MB/s  0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Building wheels for collected packages: plodlib
#   Building wheel for plodlib (pyproject.toml): started
#   Building wheel for plodlib (pyproject.toml): finished with status 'done'
#   Created wheel for plodlib: filename=plodlib-0.1.2-py3-none-any.whl size=7179 sha256=a98d3b20766659a27e83b4278c0d968013b7b754764ee0acee224224330ee4ae
#   Stored in directory: C:\Users\Kegan\AppData\Local\Temp\pip-ephem-wheel-cache-bqu49ju3\wheels\4f\a7\5b\dc8f88a7a012bd33dd692e5abab8ad0ba5536ff1005f184e05
# Successfully built plodlib
# Installing collected packages: pyparsing, rdflib, plodlib
#
#    ---------------------------------------- 0/3 [pyparsing]
#    ------------- -------------------------- 1/3 [rdflib]
#    ------------- -------------------------- 1/3 [rdflib]
#    ------------- -------------------------- 1/3 [rdflib]
#    ------------- -------------------------- 1/3 [rdflib]
#    ------------- -------------------------- 1/3 [rdflib]
#    ------------- -------------------------- 1/3 [rdflib]
#    ------------- -------------------------- 1/3 [rdflib]
#    ------------- -------------------------- 1/3 [rdflib]
#    ------------- -------------------------- 1/3 [rdflib]
#    -------------------------- ------------- 2/3 [plodlib]
#    ---------------------------------------- 3/3 [plodlib]
#
# Successfully installed plodlib-0.1.2 pyparsing-3.3.2 rdflib-7.6.0
#   Running command git clone --filter=blob:none --quiet https://github.com/p-lod/plodlib 'C:\Users\Kegan\AppData\Local\Temp\pip-req-build-o_ylyup5'

# %%
import pandas as pd
import plodlib

search_term = "spear"

result = plodlib.PLODResource(search_term)
      
    # Get images
images = result.gather_images()
print(f"Found {len(images)} images for {search_term}")
images_df = pd.DataFrame(images)


    # Get geojson if available
geojson = result.geojson
# Out:
# Found 149 images for spear
# Error afer no geojson found.

# %%
# If there's a geojson, run this! If not, you can skip to the next code block
import json

def write_geojson_to_file(geojson_data, filename):
    """
    Write GeoJSON data to a file.
    
    Args:
        geojson_data (dict): The GeoJSON data structure
        filename (str): Output filename (should end with .geojson or .json)
    """
    with open(filename, 'w') as f:
        json.dump(geojson_data, f, indent=2)

write_geojson_to_file(geojson, search_term + ".geojson") 

# now double click on the geojson file!

# %%
images_df

# %% [markdown]
# Ok, so we can get the art and its descriptors, and we can get a map very easily showing where in Pompeii these items were displayed.
#
# The code below defines a list of identifiers that we can look for. 'r1' means 'regio 1'; 'r1-i1' means regio 1 insula 1; r1-i9-p1 means regio 1 insula 9 door (porta) 1. The system for identifying locations at Pompeii can get you right down to an individual room!

# %%
import plodlib

r_list = ['pompeii','r1','r1-i1','r1-i9-p1','bird','dog','ariadne','bogus_id_bogus']

# run through instantiating ids and printing standard info
for r in r_list: # that is, for each item in the list. r = item here.
	c = plodlib.PLODResource(r) # we define a call to the plod datastore for that item, as 'c'. Then in the print statements, we can call elements from that result by appending them to 'c'.
	print(f'''*Made instance of PLODResource for "{r}" now reading from returned object
  Identifier: {c.identifier} (as passed: {c._identifier_parameter}) 
  Type: {c.rdf_type}
  Label: {c.label}
  P-in-P URL: {c.p_in_p_url}
  Wikidata URL: {c.wikidata_url}

		''')
# Out:
# *Made instance of PLODResource for "pompeii" now reading from returned object
#   Identifier: pompeii (as passed: pompeii)
#   Type: city
#   Label: Pompeii
#   P-in-P URL: https://pompeiiinpictures.com/pompeiiinpictures/pompeii.htm
#   Wikidata URL: http://www.wikidata.org/entity/Q43332
#
#
# *Made instance of PLODResource for "r1" now reading from returned object
#   Identifier: r1 (as passed: r1)
#   Type: region
#   Label: Region I
#   P-in-P URL: http://pompeiiinpictures.com/pompeiiinpictures/Plans/regio_1.htm
#   Wikidata URL: http://www.wikidata.org/entity/Q3931883
#
#
# *Made instance of PLODResource for "r1-i1" now reading from returned object
#   Identifier: r1-i1 (as passed: r1-i1)
#   Type: insula
#   Label: Insula I.1
#   P-in-P URL: http://pompeiiinpictures.com/pompeiiinpictures/Plans/plan_1_01.htm
#   Wikidata URL: http://www.wikidata.org/entity/Q26960992
#
#
# *Made instance of PLODResource for "r1-i9-p1" now reading from returned object
#   Identifier: r1-i9-p1 (as passed: r1-i9-p1)
#   Type: property
#   Label: Property I.9.1
#   P-in-P URL: http://pompeiiinpictures.com/pompeiiinpictures/R1/1%2009%2001.htm
#   Wikidata URL: None
#
#
# *Made instance of PLODResource for "bird" now reading from returned object
#   Identifier: bird (as passed: bird)
#   Type: concept
#   Label: Bird
#   P-in-P URL: None
#   Wikidata URL: http://www.wikidata.org/entity/Q5113
#
#
# *Made instance of PLODResource for "dog" now reading from returned object
#   Identifier: dog (as passed: dog)
#   Type: concept
#   Label: Dog
#   P-in-P URL: None
#   Wikidata URL: http://www.wikidata.org/entity/Q144
#
#
# *Made instance of PLODResource for "ariadne" now reading from returned object
#   Identifier: ariadne (as passed: ariadne)
#   Type: concept
#   Label: Ariadne
#   P-in-P URL: None
#   Wikidata URL: http://www.wikidata.org/entity/Q184874
#
#
# *Made instance of PLODResource for "bogus_id_bogus" now reading from returned object
#   Identifier: None (as passed: bogus_id_bogus)
#   Type: None
#   Label: None
#   P-in-P URL: None
#   Wikidata URL: None

# %% [markdown]
# Notice that the P-LOD datastore is using wikidata for entity authorities, and the site Pompeii in Pictures for some of the geographic data.
#
# Anyway, that's all for today. Do check out [https://p-lod.org/](https://p-lod.org/) and [palp](https://palp.art/start).
