# %%
# These packages are necessary - so let's install them!
# !pip install numpy
# !pip install networkx
# !pip install matplotlib
# !pip install scipy
# !pip install pandas
# Out:
# /Users/cbrou/.zshenv:13: = not found
# Requirement already satisfied: numpy in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (2.3.5)
# /Users/cbrou/.zshenv:13: = not found
# Requirement already satisfied: networkx in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (3.6.1)
# /Users/cbrou/.zshenv:13: = not found
# Requirement already satisfied: matplotlib in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from matplotlib) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# /Users/cbrou/.zshenv:13: = not found
# Requirement already satisfied: scipy in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (1.17.0)
# Requirement already satisfied: numpy<2.7,>=1.26.4 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from scipy) (2.3.5)
# /Users/cbrou/.zshenv:13: = not found
# Requirement already satisfied: pandas in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (3.0.0)
# Requirement already satisfied: numpy>=1.26.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
# %matplotlib inline

# %%
from TerrainGenerator import lloyd_relaxation, World

# %% [markdown]
# ## Generating the world map

# %%
N = 4000
#N = 2**14
points = np.random.random(size=(N, 2))
for i in range(2):
    points = lloyd_relaxation(points, (0, 1), (0, 1))
world = World(points)
world.set_heights(0.5)

# %%
world.add_slope(4)

for i in range(10):
    r = np.random.random() * 0.5
    world.add_hill(r=r)

world.normalize_heights()
world.make_rivers()
world.erode_heights()
#world.erode_heights()
world.set_sea_level(25)
world.clean_coastline()

# %%
world.draw_world(river_cutoff=0.01)

# %% [markdown]
# # Enter the nameless nomads
#
# Simulate nomadic groups wandering the world; each step, the groups evaluate adjacent patches and decide which one (if any) to move to. When two groups meet, they merge. The bigger a group is (the more times it has joined other groups) the less likely it is to move.
#
# Wherever the groups end up after 500 years is where the cities are.

# %%
from NomadModel import NomadModel

# %%
nomad_model = NomadModel(world, 1000)

# %%
for i in range(500):
    nomad_model.one_year()

# %%
fig, ax = plt.subplots(figsize=(8,8))

world.draw_world(river_cutoff=0.005, ax=ax)

for tribe in nomad_model.nomads:
    x, y = tribe.patch.centroid
    ax.scatter([x], [y], s=tribe.size, c='k', zorder=2)

# %% [markdown]
# ## Create cities
#
# The tribe locations become city locations. Each city trades with the closest other city that is larger than itself; these trade routes become roads.

# %%
class City:
    def __init__(self, patch, size):
        self.name = patch.name
        self.size = size
        self.patch = patch
        self.centroid = np.array(patch.centroid)

# %%
cities = [City(tribe.patch, tribe.size) for tribe in nomad_model.nomads]

# %%
trade_routes = []
for city in sorted(cities, key=lambda c: c.size)[:-1]:
    bigger_cities = [c for c in cities if c.size > city.size
                    if c != city]
    closest = min(bigger_cities, 
                key=lambda c: np.linalg.norm(city.centroid - c.centroid))
    trade_routes.append((city.name, closest.name))

# %%
fig, ax = plt.subplots(figsize=(8,8))

world.draw_world(river_cutoff=0.005, ax=ax)

for city in cities:
    x, y = city.patch.centroid
    ax.scatter([x], [y], s=city.size, c='k', zorder=2)

#for start, end in combinations(cities, 2):
for route in trade_routes:
    start, end = route
    if start == end: continue
    road_lines = world.make_road(start, end)
    road_lc = LineCollection(road_lines, colors='k',
                             linewidths=0.5, linestyles="--")
    ax.add_collection(road_lc)

# %% [markdown]
# ### Prepare network
#
# Build the graph of city to city roads; this graph is used to instantiate the Tribute Model, and simulate how the cities rise and fall.

# %%
G = nx.Graph()
for city in cities:
    G.add_node(city.name, wealth=city.size*10)
for c1, c2 in trade_routes:
    G.add_edge(c1, c2)

# %% [markdown]
# Give the cities more interesting (random) names

# %%
from TributeNarrative import make_word

# %%
G = nx.relabel_nodes(G, lambda x: make_word())

# %% [markdown]
# ## Tribute Model
#
# Simulate how the cities grow, fight, and ally with one another, and log their histories.

# %%
from TributeModel import Model
import pandas as pd

# %%
tribute_model = Model(G)

# %%
for i in range(100):
    tribute_model.step()

# %%
wealth_series = {a.name: a.wealth_history for a in tribute_model.agents.values()}
df = pd.DataFrame(wealth_series)
df.plot(legend=False)
# Out:
# <Axes: >

# %%
a = max(df.columns, key=lambda x: df[x].max())
print("The wealthiest city is {}".format(a))
# Out:
# The wealthiest city is Oxvig

# %% [markdown]
# ### Choose a city at random and show its history

# %%
a = np.random.choice(df.columns)
print(a)
# Out:
# Nyyqu

# %%
df[a].plot()
# Out:
# <Axes: >

# %% [markdown]
# ### Narrative
# Generate a history narrative by finding the local extrema in the city's wealth time series, using them to divide its history into eras, and report the events that occured in each era.

# %%
from TributeNarrative import get_eras, write_era

# %%
a = tribute_model.agents[a]

# %%
eras = get_eras(np.array(a.wealth_history))

# %%
for era in eras:
    print(write_era(a, era))
    print("")
# Out:
# From 0 to 71, Nyyqu saw slow growth.
#
# From 71 to 78, Nyyqu saw rapid decline. In this period it fought a war against Qeetoa.
#
# From 78 to 89, Nyyqu saw slow growth.
#
# From 89 to 90, Nyyqu saw rapid decline. In 90 it fought a war against Qeetoa.
#
# From 90 to 99, Nyyqu saw slow decline. In this period it fought a war against Qeetoa.

# %%
a.log
# Out:
# [(72, 'Led war against', 'Qeetoa'),
#  (78, 'Led war against', 'Qeetoa'),
#  (90, 'Led war against', 'Qeetoa'),
#  (99, 'Led war against', 'Qeetoa')]
